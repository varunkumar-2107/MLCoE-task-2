# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('tech_job_market_2019_2026.csv')
df.head(10)
# Out:
#       job_id              company_name company_type         sector  \
# 0  JOB041385              CobaltWealth          MNC     HealthTech
# 1  JOB018462                DriftLearn     Mid-size    Cloud/Infra
# 2  JOB110011           AnchorBuzz Labs          MNC     HealthTech
# 3  JOB073462                KiteSphere      Unicorn     HealthTech
# 4  JOB051683             AetherNode Co          MNC  Social/AdTech
# 5  JOB099770  QuantumBuzz Technologies          MNC           SaaS
# 6  JOB080320                SpireCloud          MNC        Fintech
# 7  JOB057551             EchoCortex Co          MNC  Cybersecurity
# 8  JOB019108                NimbusFlow   FAANG-tier    Crypto/Web3
# 9  JOB088302      VantageChain Systems      Startup          AI/ML
#
#    company_size_employees hq_country                   job_role  \
# 0                  146085    Germany                SOC Analyst
# 1                    5882        USA      Mobile Engineer (iOS)
# 2                  186507        USA                QA Engineer
# 3                   10930     Brazil         Research Scientist
# 4                   42510        USA            Product Manager
# 5                   86535         UK              Data Engineer
# 6                  369939        USA                UI Designer
# 7                  128882        USA  Embedded Systems Engineer
# 8                   53256         UK           Product Designer
# 9                     380     Brazil           Product Designer
#
#   seniority_level  years_experience_min  years_experience_max  ...  \
# 0             Mid                     3                     5  ...
# 1             Mid                     1                     4  ...
# 2            Lead                     7                    15  ...
# 3           Entry                     1                     4  ...
# 4          Senior                     6                     9  ...
# 5          Intern                     1                     1  ...
# 6           Entry                     0                     1  ...
# 7           Entry                     0                     4  ...
# 8             Mid                     1                     5  ...
# 9          Intern                     0                     0  ...
#
#   application_deadline date_position_filled position_status  \
# 0  2023-11-12 00:00:00           2023-11-20          Filled
# 1  2025-06-29 00:00:00                  NaN            Open
# 2  2026-01-24 00:00:00           2026-02-08          Filled
# 3  2020-12-09 00:00:00           2020-12-21          Filled
# 4  2025-07-19 00:00:00           2025-09-15          Filled
# 5  2025-09-09 00:00:00           2025-09-09          Filled
# 6  2022-06-16 00:00:00           2022-06-09          Filled
# 7  2024-05-25 00:00:00           2024-05-29          Filled
# 8  2022-04-21 00:00:00           2022-08-17          Filled
# 9  2025-05-23 00:00:00           2025-05-05          Filled
#
#   number_of_applicants number_of_interview_rounds offers_extended  \
# 0                 98.0                        4.0             5.0
# 1                134.0                        2.0             1.0
# 2                 36.0                        4.0             1.0
# 3                300.0                        1.0             6.0
# 4                 43.0                        3.0             1.0
# 5                 58.0                        2.0             1.0
# 6                281.0                        1.0             1.0
# 7                258.0                        3.0             1.0
# 8                 78.0                        4.0             1.0
# 9                349.0                        3.0             1.0
#
#   offers_accepted salary_min_usd salary_max_usd layoff_within_12_months_flag
# 0             5.0             -1             -1                            N
# 1             0.0            NaN            NaN                           No
# 2             1.0       238800.0       274700.0                            0
# 3             5.0        96300.0       104000.0                          Yes
# 4             1.0       $186,800       245400.0                            1
# 5             1.0        33100.0        38500.0                           No
# 6             3.0        87400.0        98100.0                        False
# 7             1.0       131100.0       103900.0                            N
# 8             1.0       114500.0       139700.0                            0
# 9             1.0        42500.0        47600.0                        False
#
# [10 rows x 28 columns]

# %%
df.shape
# Out:
# (115000, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115000 entries, 0 to 114999
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   job_id                        115000 non-null  object
#  1   company_name                  115000 non-null  object
#  2   company_type                  115000 non-null  object
#  3   sector                        115000 non-null  object
#  4   company_size_employees        115000 non-null  int64
#  5   hq_country                    115000 non-null  object
#  6   job_role                      115000 non-null  object
#  7   seniority_level               115000 non-null  object
#  8   years_experience_min          115000 non-null  int64
#  9   years_experience_max          115000 non-null  int64
#  10  required_tech_stack           115000 non-null  object
#  11  primary_programming_language  92525 non-null   object
#  12  work_mode                     115000 non-null  object
#  13  visa_sponsorship_offered      115000 non-null  object
#  14  job_location_country          115000 non-null  object
#  15  job_location_city             89893 non-null   object
#  16  salary_currency               115000 non-null  object
#  17  posting_date                  115000 non-null  object
#  18  application_deadline          109243 non-null  object
#  19  date_position_filled          89219 non-null   object
#  20  position_status               115000 non-null  object
#  21  number_of_applicants          113890 non-null  float64
#  22  number_of_interview_rounds    114564 non-null  float64
#  23  offers_extended               114670 non-null  float64
#  24  offers_accepted               114670 non-null  float64
#  25  salary_min_usd                111682 non-null  object
#  26  salary_max_usd                111682 non-null  object
#  27  layoff_within_12_months_flag  115000 non-null  object
# dtypes: float64(4), int64(3), object(21)
# memory usage: 24.6+ MB

# %% [markdown]
# ## there 21 object columns, 7 int columns

# %%
df.isnull().sum().sum()
# Out:
# np.int64(87962)

# %% [markdown]
# In this data there are 87962 missing data

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# date_position_filled            25781
# job_location_city               25107
# primary_programming_language    22475
# application_deadline             5757
# salary_max_usd                   3318
# salary_min_usd                   3318
# number_of_applicants             1110
# number_of_interview_rounds        436
# offers_accepted                   330
# offers_extended                   330
# job_id                              0
# position_status                     0
# posting_date                        0
# salary_currency                     0
# job_location_country                0
# company_name                        0
# visa_sponsorship_offered            0
# work_mode                           0
# required_tech_stack                 0
# years_experience_max                0
# years_experience_min                0
# seniority_level                     0
# job_role                            0
# hq_country                          0
# company_size_employees              0
# sector                              0
# company_type                        0
# layoff_within_12_months_flag        0
# dtype: int64

# %%
int_null_val_cols = ["salary_max_usd","salary_min_usd","number_of_applicants","number_of_interview_rounds","offers_accepted","offers_extended"]
obj_null_val_cols = ["date_position_filled","job_location_city","primary_programming_language","application_deadline"]

# %%
df[obj_null_val_cols] = df[obj_null_val_cols].fillna(df[obj_null_val_cols].mode)

# %%
df[df["job_id"].duplicated()].sort_values("job_id")
# Out:
#            job_id                company_name company_type         sector  \
# 97744   JOB000012                    KiteCare      Startup    Crypto/Web3
# 64353   JOB000048         MeridianShield Labs          MNC  Social/AdTech
# 48411   JOB000066           PinnacleBlock Inc          MNC    Cloud/Infra
# 59499   JOB000091                NexusCompute   FAANG-tier    Crypto/Web3
# 103282  JOB000141                GroveCapital      Startup     E-commerce
# ...           ...                         ...          ...            ...
# 17090   JOB111693                   DriftDesk      Startup           SaaS
# 65945   JOB111860                  SpireCloud          MNC        Fintech
# 71126   JOB111885     NexusToken Technologies      Startup    Cloud/Infra
# 36330   JOB111985     EmberReach Technologies   FAANG-tier     HealthTech
# 51712   JOB112036  HalcyonCampus Technologies     Mid-size  Social/AdTech
#
#         company_size_employees hq_country                   job_role  \
# 97744                      270     Brazil           DevOps Engineer
# 64353                   178480      India        Full Stack Engineer
# 48411                    40537         UK  Mobile Engineer (Android)
# 59499                   138397     Brazil             Cloud Engineer
# 103282                     333      India            DevOps Engineer
# ...                        ...        ...                        ...
# 17090                      443    Germany            Product Manager
# 65945                   241384        USA  Machine Learning Engineer
# 71126                      370  Australia  Machine Learning Engineer
# 36330                    68660         UK  Machine Learning Engineer
# 51712                     1214    Germany           Backend Engineer
#
#        seniority_level  years_experience_min  years_experience_max  ...  \
# 97744             Lead                     7                    14  ...
# 64353           Senior                     5                    11  ...
# 48411           Senior                     6                     9  ...
# 59499           Intern                     1                     1  ...
# 103282           Entry                     0                     2  ...
# ...                ...                   ...                   ...  ...
# 17090              Mid                     1                     5  ...
# 65945              Mid                     3                     5  ...
# 71126            Entry                     0                     1  ...
# 36330              Mid                     2                     5  ...
# 51712           Senior                     4                     9  ...
#
#                                      application_deadline  \
# 97744                                 2022-09-14 00:00:00
# 64353                                 2026-05-29 00:00:00
# 48411                                 2022-11-12 00:00:00
# 59499                                 2019-02-20 00:00:00
# 103282                                2022-02-07 00:00:00
# ...                                                   ...
# 17090                                 2022-02-19 00:00:00
# 65945                                 2019-09-12 00:00:00
# 71126                                 2026-09-25 00:00:00
# 36330                                 2023-06-10 00:00:00
# 51712   <bound method DataFrame.mode of        date_po...
#
#                                      date_position_filled position_status  \
# 97744                                          2022-09-18          Filled
# 64353                                          2026-06-12          Filled
# 48411                                          2022-12-05          Filled
# 59499   <bound method DataFrame.mode of        date_po...       Cancelled
# 103282  <bound method DataFrame.mode of        date_po...          Filled
# ...                                                   ...             ...
# 17090   <bound method DataFrame.mode of        date_po...            Open
# 65945                                          2019-09-21          Filled
# 71126   <bound method DataFrame.mode of        date_po...            Open
# 36330                                          2023-07-18          Filled
# 51712                                          2025-02-28          Filled
#
#        number_of_applicants number_of_interview_rounds offers_extended  \
# 97744                  28.0                        4.0             NaN
# 64353                  93.0                        3.0             1.0
# 48411                  71.0                        3.0             5.0
# 59499                 221.0                        4.0             0.0
# 103282                128.0                        2.0             1.0
# ...                     ...                        ...             ...
# 17090                 279.0                        2.0             1.0
# 65945                  99.0                        4.0             1.0
# 71126                 119.0                        1.0             6.0
# 36330                 153.0                        4.0             1.0
# 51712                  52.0                        5.0             1.0
#
#        offers_accepted salary_min_usd salary_max_usd  \
# 97744              NaN       166200.0       205100.0
# 64353              1.0       139500.0       186300.0
# 48411              5.0       160000.0       202200.0
# 59499              0.0        48300.0        61400.0
# 103282             1.0        59000.0        64900.0
# ...                ...            ...            ...
# 17090              0.0        99200.0       127700.0
# 65945              1.0        97000.0       114200.0
# 71126              4.0        64500.0        79900.0
# 36330              1.0       125100.0       166000.0
# 51712              1.0  Not Disclosed  Not Disclosed
#
#        layoff_within_12_months_flag
# 97744                             Y
# 64353                            No
# 48411                             1
# 59499                         False
# 103282                            N
# ...                             ...
# 17090                             N
# 65945                             0
# 71126                             0
# 36330                             N
# 51712                             N
#
# [2000 rows x 28 columns]

# %% [markdown]
# Here as we see there us 2000 rows which is duplicated on the basis of job_id

# %%
df.drop_duplicates(subset=["job_id"], inplace=True)
df["job_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (113000, 28)

# %%
cat_cols = df.select_dtypes(include='object').columns
for col in cat_cols:
    print(f"Column: {col}")
    print(df[col].unique())
    print("\n")
# Out:
# Column: job_id
# ['JOB041385' 'JOB018462' 'JOB110011' ... 'JOB006013' 'JOB063108'
#  'JOB006559']
#
#
# Column: company_name
# ['CobaltWealth' 'DriftLearn' 'AnchorBuzz Labs' 'KiteSphere'
#  'AetherNode Co' 'QuantumBuzz Technologies' 'SpireCloud' 'EchoCortex Co'
#  'NimbusFlow' 'VantageChain Systems' 'PinnacleBlock'
#  'EchoVita Technologies' 'MeridianToken' 'BeaconStack Co'
#  'LumenArcade Technologies' 'VertexCompute Inc' 'PinnacleLedger Labs'
#  'AstraCognition' 'PrismSphere' 'NovaFleet' 'PrismRoute Technologies'
#  'MeridianShield Labs' 'DriftGame Co' 'DriftSkill Inc' 'RidgeAI'
#  'CatalystWellness Inc' 'EchoTrade Co' 'OnyxBuzz Inc' 'NexusShield'
#  'FusionTrade' 'VantageSphere' 'CobaltAcademy Labs' 'SolaceFlow Inc'
#  'AstraSuite' 'SolaceShop Labs' 'VantageFlow' 'DriftGame'
#  'LumenNeural Inc' 'LatticeReach Systems' 'SpireBazaar Co' 'OrbitWorks'
#  'KitePlay Inc' 'NimbusGame Technologies' 'LUMENARCADE TECHNOLOGIES'
#  'DriftShield Labs' '  OnyxBuzz Co' 'CrestMind Systems' 'NovaCare'
#  'TideFort' 'AetherFleet Inc' 'WrenShop Systems'
#  'OrbitNeural Technologies' 'AetherAI Co' 'NexusTrade Labs'
#  'ZenithReach Systems' 'CatalystHub Co' 'QuantumReach Co'
#  'TideSentinel Technologies' 'NimbusAcademy' 'NexusCompute'
#  'VertexBlock Inc  ' 'OnyxSphere Inc' '  AstraCognition'
#  'EchoFreight Systems' 'WrenShop Technologies' 'ZephyrQuest Co'
#  'RidgeFreight Labs' 'BeaconPixel' 'PrismGuard' 'HelixMed Labs'
#  'RuneCompute' 'HelixFin Inc' 'AstraAcademy' 'GroveSocial'
#  'EchoFreight Labs' 'RuneMarket' 'DriftNeural Systems' 'WrenSocial'
#  'LatticePlay Inc' 'EchoMed' 'HalcyonFleet Systems' 'VertexNode Inc'
#  'FusionTrade  ' 'PinnacleBlock Inc' 'NexusFin Inc' 'HelixVita Co'
#  'OrbitShield Systems' 'FalconAcademy Technologies' 'COBALTWEALTH'
#  'PinnacleToken Technologies' 'QuantumCognition Labs' 'VertexBlock Inc'
#  'NexusToken Technologies' 'EmberReach Technologies' 'AstraSecure Systems'
#  'CobaltBlock Systems' 'NimbusCargo Systems' 'VantageSuite'
#  'QuantumHub Inc' 'NexusWellness Labs' 'PrismMarket Labs' 'AetherLearn'
#  'VertexTrade Systems' 'GroveCapital' 'ZenithShield Inc' 'VertexSkill'
#  'RidgeFleet' 'KiteWorks Inc' 'EmberEdu Labs' 'VantageStack Inc'
#  'ZephyrWealth Technologies' 'AETHERAI CO' 'TideCognition Technologies'
#  '  RidgeFreight Labs' '  NimbusTrade Labs' 'SummitShield Co'
#  'FalconPlay Technologies' 'LatticeLedger Inc' 'SolaceWealth Systems'
#  'RidgeSecure Systems' 'LumenCloud' 'RidgeFleet Labs' 'WrenCampus'
#  'CatalystChain' 'RidgeCargo' 'HalcyonLedger Co' 'HelixRoute Systems'
#  'RuneFleet Co' 'OrbitGame' 'MeridianFleet Co' 'VertexFlow Inc'
#  'DriftQuest' 'NimbusTrade Labs' 'KiteCare' 'OrbitWealth Co' 'HelixGuard'
#  'FusionBazaar Technologies' 'CrestRoute Labs' 'BeaconCampus'
#  'VantageCargo Systems' 'NexusShield  ' 'SPIRECLOUD' 'RuneConnect Co'
#  'CrestLearn' 'tidefort' 'EmberRoute Technologies'
#  'RidgeSecure Systems   ' 'ZenithHealth Systems' 'onyxsphere inc'
#  'NexusSecure' 'NEXUSCOMPUTE' '  OrbitNeural Technologies'
#  'MarrowChain Systems' 'RidgeVita Co' 'AetherNode' 'SpireHub Inc'
#  'MeridianCare Systems' 'CobaltCampus Labs' 'MeridianReach Inc'
#  'RidgeTrade Technologies' 'OnyxBuzz Co' 'OnyxCognition Inc'
#  'pinnacleledger labs' 'HalcyonConnect' 'DriftCognition Technologies'
#  'VertexNeural Technologies' 'HelixPixel' 'TideFort  ' 'PinnacleSphere'
#  'NimbusChain' 'QuantumFort Co' 'HalcyonCampus Technologies'
#  'pinnacleblock inc' 'RIDGECARGO' 'NIMBUSCARGO SYSTEMS' 'VantageVita Co'
#  'ridgefreight labs' 'AstraVault Co' 'SolaceGuard' 'TideQuest'
#  'OnyxNode Labs' 'LatticeHub' 'NexusDesk Labs' 'TideMarket Technologies'
#  'MeridianPixel Co' 'RidgeVita Labs' 'PrismGuard Co' 'SummitMarket'
#  'FableConnect Technologies' 'LatticeMarket Systems' 'AETHERNODE CO'
#  'CatalystConnect Co' 'DriftNode Labs' 'OnyxWorks Systems' 'FableLogix'
#  'NovaArcade Co' 'AstraWellness' 'HALCYONLEDGER CO' 'HalcyonLedger Inc'
#  'NimbusFleet Inc' '  HelixRoute Systems' 'MeridianLogix Co'
#  'VantageLogix' '  CobaltWealth' 'CatalystHealth Labs' '  KiteSphere'
#  '  SolaceFlow Inc' 'ECHOFREIGHT SYSTEMS' 'RidgeCapital'
#  'ZephyrHealth Systems' 'CatalystCapital Labs' '  BeaconStack Co'
#  '  PrismRoute Technologies' 'DriftDesk' 'DRIFTGAME CO' 'HelixStack'
#  'FusionSocial Labs' 'vertexblock inc' 'BeaconPixel ' 'PINNACLEBLOCK'
#  'NovaGrid Inc' 'BeaconFin Inc' '  TideFort' '  NovaFleet'
#  '  DriftSkill Inc' 'SpireGame Labs' 'ONYXCOGNITION INC' 'DriftGame Co '
#  'MeridianSocial' 'AetherFleet Inc  ' 'RuneDesk Systems'
#  'HalcyonToken Labs' 'MeridianToken ' 'FusionMarket Systems'
#  'NexusCompute  ' 'VERTEXTRADE SYSTEMS' 'AetherVault Co' 'ANCHORBUZZ LABS'
#  'fusionfort' 'LatticeReach Systems  ' '  ZenithHealth Systems'
#  'GroveTrade Inc' 'LATTICEREACH SYSTEMS' 'EchoCortex Co  ' 'AetherFlow'
#  'NimbusQuest' 'HelixStack  ' '  OrbitWorks' '  MarrowChain Systems'
#  'driftgame co' 'SpireCloud  ' 'AnchorBuzz Labs  ' 'nimbusflow'
#  '  MeridianFleet Co' 'BEACONSTACK CO' '  NexusShield' 'NEXUSSHIELD'
#  'echocortex co' 'SolaceShop Labs  ' 'ZephyrQuest Co  ' '  PinnacleBlock'
#  'HelixCare Systems' 'SolaceWealth Systems  ' 'astrasuite'
#  'DriftCognition Systems' '  FusionTrade' 'EMBERROUTE TECHNOLOGIES'
#  'HalcyonLedger Co ' 'NEXUSWELLNESS LABS' 'COBALTACADEMY LABS'
#  '  MeridianShield Labs' 'nexusshield' '  ZenithShield Inc' 'BEACONPIXEL'
#  'ORBITNEURAL TECHNOLOGIES' '  AetherAI Co' '  RuneCompute' 'FusionTrade '
#  '  DriftGame Co' 'PinnacleBlock ' 'BeaconFin Inc '
#  'LatticeReach Systems ' 'FusionMind' 'RUNEMARKET' 'PinnaclePixel'
#  'RidgePixel Systems' 'cobaltwealth' 'RIDGEFREIGHT LABS' 'onyxbuzz inc'
#  'PRISMROUTE TECHNOLOGIES' '  AstraSuite' 'grovesocial'
#  '  LatticeReach Systems' 'EchoCortex Co ' '  TideQuest'
#  'meridianreach inc' 'astraacademy' 'ridgefleet labs' 'beaconstack co'
#  'AetherCognition' '  HelixGuard' '  MeridianToken' 'vertexskill'
#  '  VantageSuite' '  SolaceShop Labs' 'LUMENNEURAL INC' 'spirecloud'
#  'NEXUSTRADE LABS' '  BeaconPixel' 'marrowchain systems'
#  '  PinnacleLedger Labs' 'NovaCare  ' 'NOVAFLEET' 'catalystconnect co'
#  'GROVESOCIAL' 'PRISMMARKET LABS' 'NimbusCargo Systems  ' '  NexusCompute'
#  'FusionFort' 'NIMBUSACADEMY' 'ZenithHealth Systems  ' 'BeaconStack Co '
#  'OrbitVault Labs' 'orbitgame' 'kitesphere' 'zenithshield inc'
#  'EMBERREACH TECHNOLOGIES' 'RidgeFleet Labs  '
#  'OrbitNeural Technologies  ' '  VertexBlock Inc' 'EchoFreight Systems  '
#  'RidgeFreight Labs ' 'CobaltWealth  ' 'ZENITHHEALTH SYSTEMS'
#  'BeaconStack Co  ' '  NimbusFlow' 'DriftSkill Inc  '
#  'TideSentinel Technologies  ' 'VertexTrade Systems  ' '  LumenNeural Inc'
#  'AstraSuite ' 'ZephyrWealth Technologies  ' 'NovaFleet  '
#  'PrismRoute Technologies ' 'ASTRAACADEMY' 'MERIDIANTOKEN'
#  'DRIFTSKILL INC' 'OrbitNeural Technologies ' '  SummitMarket'
#  'LATTICEPLAY INC' 'VANTAGECARGO SYSTEMS' 'TIDECOGNITION TECHNOLOGIES'
#  'HELIXGUARD' 'NEXUSTOKEN TECHNOLOGIES' '  EchoMed'
#  '  EmberReach Technologies' 'MERIDIANPIXEL CO' 'LumenAI Inc'
#  'KiteSphere  ' 'SpireCloud ' 'MeridianPixel Co '
#  'PinnacleToken Technologies  ' 'kiteplay inc' 'cobaltacademy labs'
#  'LatticePlay Inc ' 'PINNACLEBLOCK INC' 'echomed' 'nexuswellness labs'
#  'MeridianShield Labs  ' 'emberreach technologies' '  BeaconFin Inc'
#  '  AetherNode Co' 'PinnacleLedger Labs ' 'QuantumReach Co  '
#  '  VertexCompute Inc' 'NexusTrade Labs  ' 'runecompute' '  EchoCortex Co'
#  'MERIDIANCARE SYSTEMS' 'ORBITSHIELD SYSTEMS' 'MARROWCHAIN SYSTEMS'
#  'RidgeFreight Labs  ' '  OrbitWealth Co' '  PrismGuard' 'RidgeCargo '
#  'zenithhealth systems' 'SummitMarket ' '  FusionBazaar Technologies'
#  '  VertexNode Inc' '  AnchorBuzz Labs' 'meridiantoken' 'RIDGECAPITAL'
#  '  RidgeSecure Systems' 'NexusShield ' 'RidgeVita Co  ' 'aethernode co'
#  'VantageSuite  ' 'TIDEFORT' 'RUNECOMPUTE' 'VERTEXSKILL'
#  'PINNACLELEDGER LABS' '  CatalystWellness Inc' 'WrenSuite Co'
#  '  CatalystConnect Co' 'MeridianShield Labs ' 'MERIDIANSHIELD LABS'
#  'CobaltAcademy Labs ' '  KitePlay Inc' 'VANTAGESUITE'
#  'PINNACLETOKEN TECHNOLOGIES' 'MeridianToken  ' 'LumenAI Inc  '
#  'NEXUSFIN INC' 'pinnacletoken technologies' 'AnchorLogix Technologies'
#  'CobaltWealth ' 'NimbusFlow  ' 'NimbusGrid Co' 'nexuscompute'
#  'vertexcompute inc' 'ONYXBUZZ INC' 'pinnacleblock' 'VERTEXBLOCK INC'
#  'GROVETRADE INC' 'beaconpixel' 'ASTRACOGNITION' 'PrismMarket Labs  '
#  'NovaFleet ' 'ZEPHYRHEALTH SYSTEMS' 'driftgame co ' 'novafleet '
#  'EchoFreight Systems ' 'nimbusacademy' 'LATTICEMARKET SYSTEMS'
#  'HELIXMED LABS' 'tidecognition technologies' 'NOVACARE'
#  '  QuantumBuzz Technologies' 'VertexBlock Inc '
#  '  TideCognition Technologies' 'HalcyonCampus Technologies  '
#  '  HelixVita Co' 'catalysthub co' 'vertexnode inc' '  NovaCare'
#  'AetherNode Co ' 'VertexCompute Inc  ' 'LumenNeural Inc  '
#  'VERTEXCOMPUTE INC' 'DRIFTSHIELD LABS' 'AnchorBuzz Labs '
#  'EmberEdu Labs ' 'KitePlay Inc ' '  HelixMed Labs' 'PinnacleBlock  '
#  'echofreight systems' 'fusionmarket systems' 'lumenneural inc'
#  'DriftSkill Inc ' 'RIDGETRADE TECHNOLOGIES' 'DRIFTNODE LABS'
#  'RidgeFleet Labs ' 'latticeledger inc' 'CATALYSTCAPITAL LABS'
#  'NimbusTrade Labs ' 'OnyxNode Labs  ' 'RidgeTrade Technologies  '
#  '  DriftDesk' '  LumenArcade Technologies' 'QuantumBuzz Technologies '
#  'KITESPHERE' '  OnyxSphere Inc' 'AetherAI Co  ' 'ridgeai' '  SpireCloud'
#  '  WrenCampus' 'meridianshield labs' 'RuneMarket  ' 'cobaltblock systems'
#  'VantageStack Inc  ' 'AetherAI Co ' 'DriftNeural Systems ' 'ECHOMED'
#  'CRESTLEARN' 'meridianfleet co' 'VANTAGESTACK INC' '  BEACONSTACK CO'
#  'VANTAGESPHERE' 'HelixGuard  ' 'DriftGame Co  ' 'RidgeSecure Systems '
#  '  PinnacleBlock Inc' 'TIDESENTINEL TECHNOLOGIES'
#  'lumenarcade technologies' 'echofreight labs' 'catalystcapital labs'
#  '  FusionMind' 'anchorbuzz labs' 'WRENCAMPUS' 'EmberReach Technologies  '
#  'HELIXFIN INC' 'GroveSocial ' 'VertexCompute Inc ' 'QuantumHub Inc  '
#  '  OnyxBuzz Inc' '  DriftGame' '  NimbusFleet Inc'
#  'LumenArcade Technologies  ' '  NimbusChain' 'SolaceShop Labs '
#  '  CatalystChain' 'ECHOCORTEX CO' 'LumenNeural Inc ' 'DriftNode Labs '
#  '  QuantumCognition Labs' 'AETHERNODE' 'HalcyonToken Labs  '
#  'FUSIONTRADE' 'NIMBUSTRADE LABS' '  AstraAcademy'
#  'TideCognition Technologies ' 'nexusdesk labs' '  VertexSkill'
#  'helixvita co' 'CatalystWellness Inc  ' 'aetherai co' 'RIDGEVITA CO'
#  'RIDGESECURE SYSTEMS' 'HelixFin Inc ' '  RidgeCargo' 'vantagestack inc'
#  '  EchoFreight Labs' 'orbitneural technologies' '  AetherFlow'
#  'LumenArcade Technologies ' 'orbitworks' 'QuantumReach Co '
#  '  MeridianCare Systems' 'NIMBUSGAME TECHNOLOGIES' '  KITEPLAY INC'
#  'CatalystChain  ' '  NEXUSCOMPUTE' 'ONYXSPHERE INC' 'OrbitGame '
#  'novacare' 'PrismRoute Technologies  ' 'fusiontrade' '  PinnacleBlock '
#  'BEACONFIN INC' '  EchoFreight Systems' 'OrbitGame  ' 'QUANTUMHUB INC'
#  '  QuantumReach Co' 'AstraSuite  ' 'VERTEXNEURAL TECHNOLOGIES'
#  'EmberReach Technologies ' 'vertexneural technologies' 'AETHERLEARN'
#  'solaceshop labs' 'CATALYSTHUB CO' 'AstraWellness  ' 'fusionmind'
#  '  AetherLearn' 'MeridianCare Systems ' 'HelixRoute Systems '
#  'quantumbuzz technologies' 'RidgeSecure Systems  ' 'NimbusTrade Labs  '
#  'RUNECONNECT CO' 'BeaconPixel  ' '  FableLogix'
#  'ZephyrWealth Technologies ' 'QUANTUMBUZZ TECHNOLOGIES'
#  '  DriftShield Labs' '  VantageSphere' '  CobaltAcademy Labs'
#  'BeaconCampus ' '  NexusSecure' 'KiteCare ' 'HelixMed Labs '
#  'FusionBazaar Technologies  ' 'PinnacleBlock Inc  ' 'driftneural systems'
#  'DriftCognition Systems ' 'MERIDIANFLEET CO' '  RidgeFleet Labs'
#  'ASTRASUITE' '  HalcyonLedger Inc' 'HalcyonFleet Systems  ' 'driftdesk'
#  'ZEPHYRQUEST CO' 'DRIFTNEURAL SYSTEMS' 'TideQuest  ' 'AetherNode Co  '
#  'FALCONPLAY TECHNOLOGIES' 'SolaceGuard ' 'helixmed labs'
#  '  VertexNeural Technologies' 'NovaGrid Inc ' 'NIMBUSFLOW'
#  'MeridianFleet Co   ' 'RuneConnect Co  ' 'zephyrquest co' 'RuneMarket '
#  'SPIREHUB INC' '  SummitShield Co' '  RuneConnect Co' 'helixpixel'
#  'SOLACESHOP LABS' 'helixcare systems' 'AstraCognition '
#  'prismroute technologies' '  NimbusCargo Systems' 'DriftGame  '
#  'AstraAcademy  ' 'driftskill inc' 'MeridianPixel Co  ' 'AstraCognition  '
#  'nimbuscargo systems' 'fusionbazaar technologies' '  OrbitGame'
#  'GroveTrade Inc ' 'DriftShield Labs  ' 'CrestMind Systems  '
#  '  VantageVita Co' 'novafleet' 'MERIDIANLOGIX CO' 'ridgecargo'
#  'FalconPlay Technologies  ' 'NIMBUSGRID CO' '  RUNEMARKET'
#  'LatticeLedger Inc  ' 'RUNEDESK SYSTEMS' '  KiteWorks Inc'
#  'AstraSecure Systems  ' 'LatticeMarket Systems ' 'ONYXNODE LABS'
#  'ASTRASECURE SYSTEMS' '  NimbusGame Technologies' '  RIDGEFREIGHT LABS'
#  'NovaCare ' 'BEACONCAMPUS' 'OrbitShield Systems  ' 'ECHOFREIGHT LABS'
#  'DRIFTLEARN' 'EmberRoute Technologies  ' '  RuneMarket'
#  'ZenithReach Systems ' '  HalcyonFleet Systems' 'KitePlay Inc  '
#  'LUMENCLOUD' '  AetherNode' 'FusionFort  ' 'runeconnect co'
#  '  FusionSocial Labs' 'PinnacleLedger Labs  ' '  DriftQuest'
#  'CobaltWealth   ' 'SOLACEWEALTH SYSTEMS' 'TIDEMARKET TECHNOLOGIES'
#  'CatalystCapital Labs  ' 'solacewealth systems' 'PRISMGUARD'
#  '  ZephyrWealth Technologies' '  SpireBazaar Co' 'AstraVault Co  '
#  '  VertexTrade Systems' '  CatalystHub Co' '  PinnacleToken Technologies'
#  '  NovaGrid Inc' 'HALCYONFLEET SYSTEMS' 'ZEPHYRWEALTH TECHNOLOGIES'
#  'SUMMITSHIELD CO' 'SolaceFlow Inc ' 'ORBITWORKS' 'FUSIONSOCIAL LABS'
#  'HELIXCARE SYSTEMS' '  DriftSkill Inc  ' 'HelixMed Labs  '
#  'VERTEXNODE INC' 'OnyxBuzz Inc  ' 'QuantumBuzz Technologies  '
#  'COBALTCAMPUS LABS' '  RidgeVita Co' 'VantageChain Systems  '
#  'FABLELOGIX' 'WrenCampus  ' 'SolaceFlow Inc  ' 'WrenCampus '
#  'EchoFreight Labs ' 'HalcyonFleet Systems ' '  CobaltBlock Systems'
#  '  VantageStack Inc' 'wrenshop technologies' 'zephyrwealth technologies'
#  '  QuantumHub Inc' 'VertexSkill ' 'NexusWellness Labs  ' 'wrencampus'
#  'TideQuest ' '  OnyxWorks Systems' 'astrasecure systems'
#  'TideSentinel Technologies ' 'WRENSHOP TECHNOLOGIES' 'LATTICELEDGER INC'
#  'OrbitWorks ' 'RIDGEFLEET LABS' 'SOLACEFLOW INC' 'ZENITHSHIELD INC'
#  '  RidgePixel Systems' '  HalcyonLedger Co' 'RidgeCargo  '
#  'AstraAcademy ' 'NEXUSDESK LABS' 'aethernode' 'summitshield co'
#  '  RuneDesk Systems' 'MarrowChain Systems ' 'ORBITGAME'
#  'ridgetrade technologies' 'helixguard' 'PinnacleToken Technologies '
#  'EchoFreight Labs  ' 'DRIFTGAME' 'VantageSphere  ' 'OrbitWorks  '
#  'falconplay technologies' '  NexusWellness Labs' '  DriftLearn'
#  'RuneDesk Systems  ' 'halcyonfleet systems' 'NimbusFlow '
#  'nimbusgame technologies' 'NimbusChain  ' 'latticeplay inc'
#  'LumenCloud  ' 'VertexNode Inc  ' 'NexusToken Technologies  '
#  '  ZephyrQuest Co' 'astravault co' '  ZenithReach Systems' 'AetherFlow '
#  'VantageVita Co  ' 'TIDEQUEST' 'RidgePixel Systems  ' '  NexusFin Inc'
#  '  MeridianPixel Co' 'VantageSuite ' 'FableLogix  '
#  'ZenithReach Systems  ' 'runemarket' 'TideFort ' 'ridgevita co'
#  'ridgesecure systems' 'NimbusGame Technologies  ' 'KiteSphere '
#  'latticemarket systems' 'NexusCompute ' '  GroveCapital'
#  'EmberRoute Technologies ' 'DriftQuest  ' 'VantageSphere ' 'FUSIONMIND'
#  'PinnacleBlock   ' '  GroveSocial' '  DriftCognition Systems'
#  'LATTICEHUB' 'ORBITWEALTH CO' 'NexusWellness Labs ' '  BeaconCampus'
#  'meridianlogix co' 'spirebazaar co' 'EchoMed ' 'HALCYONTOKEN LABS'
#  'CobaltBlock Systems  ' 'tidequest' 'NOVAARCADE CO' 'PINNACLEBLOCK INC  '
#  'onyxnode labs' 'LatticePlay Inc  ' '  NexusTrade Labs' 'GroveSocial  '
#  'FUSIONBAZAAR TECHNOLOGIES' 'QUANTUMREACH CO' '  nexuscompute'
#  'VertexTrade Systems ' '  FalconPlay Technologies' 'RuneCompute  '
#  'prismmarket labs' 'halcyonledger co' 'crestmind systems'
#  '  HalcyonConnect' 'MarrowChain Systems  ' 'ZenithShield Inc  '
#  'HalcyonLedger Inc ' 'halcyonledger inc' '  SolaceWealth Systems'
#  '  NexusToken Technologies' '  AetherVault Co'
#  '  TideSentinel Technologies' 'DriftNeural Systems  ' 'HelixVita Co '
#  'KiteCare  ' 'solaceflow inc' 'CatalystHub Co  ' 'driftlearn'
#  '  NimbusAcademy' 'TideCognition Technologies  ' 'SUMMITMARKET'
#  '  LatticeHub' '  EchoTrade Co' 'WrenSocial  ' 'NexusDesk Labs '
#  'RuneConnect Co ' '  WrenShop Systems' '  LatticeLedger Inc'
#  'meridianpixel co' 'ZENITHREACH SYSTEMS' 'RUNEFLEET CO'
#  'AstraSecure Systems ' 'KITEWORKS INC' '  AstraSecure Systems'
#  '  DriftNeural Systems' 'WrenShop Technologies  '
#  'VertexNeural Technologies  ' '  LatticePlay Inc' 'meridiancare systems'
#  'vantagesphere' 'VantageVita Co ' 'LatticeLedger Inc ' 'HELIXSTACK'
#  'OnyxBuzz Inc ' 'RuneDesk Systems ' 'DRIFTQUEST' 'catalystchain'
#  'latticereach systems' '  HelixFin Inc' 'RIDGEFLEET'
#  '  QUANTUMBUZZ TECHNOLOGIES' 'AetherNode ' '  QuantumFort Co'
#  'catalystwellness inc' 'RidgeVita Co ' 'EchoTrade Co  ' 'nexusfin inc'
#  'nexussecure' '  HalcyonToken Labs' '  NexusCompute ' 'DriftLearn  '
#  'meridiansocial' 'VERTEXFLOW INC' 'VANTAGEFLOW' 'PinnaclePixel  '
#  'AetherNode  ' 'HalcyonLedger Co  ' 'helixroute systems' 'summitmarket'
#  'FableLogix ' 'driftgame' '  MeridianLogix Co' 'aetherfleet inc'
#  'DriftGame ' 'MeridianFleet Co  ' 'VertexSkill  ' '  DriftNode Labs'
#  'MeridianFleet Co ' 'runefleet co' 'KiteWorks Inc ' 'MeridianLogix Co  '
#  'MeridianSocial  ' 'tidesentinel technologies' 'RuneCompute '
#  'PinnacleBlock Inc ' 'FalconAcademy Technologies  ' 'aethervault co'
#  '  NovaArcade Co' '  RidgeFleet' 'AetherLearn ' 'astracognition'
#  'AETHERVAULT CO' 'COBALTBLOCK SYSTEMS' 'quantumcognition labs'
#  'nimbuschain' 'HelixCare Systems ' 'CatalystConnect Co '
#  'QUANTUMCOGNITION LABS' 'AetherCognition  ' 'CatalystConnect Co  '
#  '  EmberRoute Technologies' 'SummitShield Co  ' 'beaconcampus'
#  '  OnyxCognition Inc' '  AetherFleet Inc' 'AETHERCOGNITION'
#  '  MeridianReach Inc' 'NovaArcade Co  ' '  SpireHub Inc'
#  'CATALYSTCONNECT CO']
#
#
# Column: company_type
# ['MNC' 'Mid-size' 'Unicorn' 'FAANG-tier' 'Startup']
#
#
# Column: sector
# ['HealthTech' 'Cloud/Infra' 'Social/AdTech' 'SaaS' 'Fintech'
#  'Cybersecurity' 'Crypto/Web3' 'AI/ML' 'E-commerce' 'EdTech' 'Logistics'
#  'Gaming' 'cloud/infra' 'gaming' 'crypto/web3' 'ai/ml' 'saas' 'edtech'
#  'logistics' 'social/adtech' 'cybersecurity' 'healthtech' 'e-commerce'
#  'fintech']
#
#
# Column: hq_country
# ['Germany' 'USA' 'Brazil' 'UK' 'Singapore' 'India' 'France' 'Netherlands'
#  'Canada' 'Israel' 'UAE' 'Australia' 'Ireland']
#
#
# Column: job_role
# ['SOC Analyst' 'Mobile Engineer (iOS)' 'QA Engineer' 'Research Scientist'
#  'Product Manager' 'Data Engineer' 'UI Designer'
#  'Embedded Systems Engineer' 'Product Designer'
#  'Mobile Engineer (Android)' 'Platform Engineer' 'Full Stack Engineer'
#  'Backend Engineer' 'Application Security Engineer' 'Software Engineer'
#  'Machine Learning Engineer' 'DevOps Engineer' 'Frontend Engineer'
#  'Data Analyst' 'Product Owner' 'Infrastructure Engineer'
#  'Associate Product Manager' 'Analytics Engineer' 'Data Scientist'
#  'Technical Program Manager' 'UX Designer' 'Site Reliability Engineer'
#  'Security Engineer' 'Penetration Tester' 'Cloud Engineer'
#  'INFRASTRUCTURE ENGINEER' 'UX Researcher' 'technical program manager'
#  ' Frontend Engineer' 'Mobile Engineer (iOS) ' 'Full Stack Engineer '
#  'SITE RELIABILITY ENGINEER' ' Analytics Engineer' 'devops engineer'
#  'mobile engineer (ios)' 'DATA ENGINEER' 'APPLICATION SECURITY ENGINEER'
#  'cloud engineer' ' Embedded Systems Engineer' 'infrastructure engineer'
#  ' Product Owner' ' Application Security Engineer' 'Product Owner '
#  'Embedded Systems Engineer ' 'PLATFORM ENGINEER'
#  ' Technical Program Manager' 'Mobile Engineer (Android) '
#  'Product Manager ' 'Software Engineer ' ' Mobile Engineer (iOS)'
#  'frontend engineer' ' Data Engineer' 'product owner' ' UI Designer'
#  'data scientist' 'UX Designer ' 'ui designer' 'platform engineer'
#  'Research Scientist ' 'Data Engineer ' 'data engineer' 'backend engineer'
#  ' Penetration Tester' 'QA Engineer ' 'software engineer' 'qa engineer'
#  'Security Engineer ' 'embedded systems engineer' ' Product Designer'
#  'SOC Analyst ' ' Data Scientist' ' UX Designer'
#  'ASSOCIATE PRODUCT MANAGER' ' UX Researcher' 'DevOps Engineer '
#  'FRONTEND ENGINEER' 'mobile engineer (android)' ' QA Engineer '
#  'Cloud Engineer ' ' Infrastructure Engineer' 'site reliability engineer'
#  'product designer' ' SOC Analyst' ' Full Stack Engineer' 'UX RESEARCHER'
#  'Backend Engineer ' ' Security Engineer' 'SOFTWARE ENGINEER'
#  'FULL STACK ENGINEER' 'Frontend Engineer ' 'EMBEDDED SYSTEMS ENGINEER'
#  'associate product manager' 'DATA SCIENTIST' 'Data Analyst '
#  'research scientist' ' Mobile Engineer (Android)' ' QA Engineer'
#  ' Product Manager' 'Machine Learning Engineer ' 'ux designer'
#  'MOBILE ENGINEER (IOS)' 'penetration tester' ' Cloud Engineer'
#  'data analyst' 'analytics engineer' ' Research Scientist'
#  'machine learning engineer' 'Analytics Engineer '
#  'Associate Product Manager ' ' Site Reliability Engineer' 'DATA ANALYST'
#  ' Data Analyst' 'UI Designer ' ' Backend Engineer' 'QA ENGINEER'
#  'product manager' 'Site Reliability Engineer ' 'DEVOPS ENGINEER'
#  'Technical Program Manager ' 'application security engineer'
#  'CLOUD ENGINEER' ' DevOps Engineer' ' Software Engineer'
#  ' Platform Engineer' 'BACKEND ENGINEER' ' Machine Learning Engineer'
#  'RESEARCH SCIENTIST' 'SOC ANALYST' 'PRODUCT DESIGNER' 'ux researcher'
#  'MACHINE LEARNING ENGINEER' 'ANALYTICS ENGINEER' 'security engineer'
#  'Data Scientist ' 'Application Security Engineer ' 'full stack engineer'
#  'MOBILE ENGINEER (ANDROID)' 'Product Designer ' 'SECURITY ENGINEER'
#  'PENETRATION TESTER' ' Associate Product Manager'
#  'Infrastructure Engineer ' 'soc analyst' 'Penetration Tester '
#  'UI DESIGNER' 'UX Researcher ' 'TECHNICAL PROGRAM MANAGER' 'UX DESIGNER'
#  'PRODUCT OWNER' 'PRODUCT MANAGER' 'Platform Engineer '
#  ' FRONTEND ENGINEER' ' Data Analyst ' ' Mobile Engineer (iOS) '
#  ' DATA ENGINEER']
#
#
# Column: seniority_level
# ['Mid' 'Lead' 'Entry' 'Senior' 'Intern' 'Principal']
#
#
# Column: required_tech_stack
# ['AWS Security Hub, Burp Suite, Splunk' 'C++, TypeScript, Python, Kotlin'
#  'Swift, C++, Kotlin, Python' ... 'Spark, TensorFlow, Python, Snowflake'
#  'React, Java, Swift, TypeScript, Kotlin'
#  'Kotlin, C++, Python, Node.js, Swift']
#
#
# Column: primary_programming_language
# ['Go' 'Python' 'R'
#  <bound method DataFrame.mode of        date_position_filled job_location_city primary_programming_language  \
#  0                2023-11-20            Munich                           Go
#  1                       NaN               NaN                       Python
#  2                2026-02-08     San Francisco                           Go
#  3                2020-12-21         Frankfurt                            R
#  4                2025-09-15              Pune                          NaN
#  ...                     ...               ...                          ...
#  114995           2025-12-21         Cambridge                       Kotlin
#  114996                  NaN               NaN                            R
#  114997                  NaN          Waterloo                          SQL
#  114998                  NaN            Mumbai                          NaN
#  114999           2021-02-16         Amsterdam                         Java
#
#         application_deadline
#  0       2023-11-12 00:00:00
#  1       2025-06-29 00:00:00
#  2       2026-01-24 00:00:00
#  3       2020-12-09 00:00:00
#  4       2025-07-19 00:00:00
#  ...                     ...
#  114995  2025-11-14 00:00:00
#  114996                  NaN
#  114997  2024-02-09 00:00:00
#  114998  2024-09-04 00:00:00
#  114999  2021-01-02 00:00:00
#
#  [115000 rows x 4 columns]>
#  'Scala' 'Kotlin' 'JavaScript' 'TypeScript' 'C++' 'Bash' 'Java' 'SQL'
#  'Swift' 'C' 'Unknown' 'TBD']
#
#
# Column: work_mode
# ['Hybrid' 'Remote' 'Onsite' 'HYBRID' 'In-office' 'hybrid' 'remote' 'WFH'
#  'onsite' 'REMOTE' 'ONSITE' 'On-site' 'Work From Home']
#
#
# Column: visa_sponsorship_offered
# ['N' 'No' 'Y' '0' 'False' 'Yes' 'True' '1']
#
#
# Column: job_location_country
# ['Germany' 'USA' 'India' 'UK' 'Brazil' 'Israel' 'Singapore' 'Netherlands'
#  'Canada' 'UAE' 'France' 'Australia' 'Ireland']
#
#
# Column: job_location_city
# ['Munich'
#  <bound method DataFrame.mode of        date_position_filled job_location_city primary_programming_language  \
#  0                2023-11-20            Munich                           Go
#  1                       NaN               NaN                       Python
#  2                2026-02-08     San Francisco                           Go
#  3                2020-12-21         Frankfurt                            R
#  4                2025-09-15              Pune                          NaN
#  ...                     ...               ...                          ...
#  114995           2025-12-21         Cambridge                       Kotlin
#  114996                  NaN               NaN                            R
#  114997                  NaN          Waterloo                          SQL
#  114998                  NaN            Mumbai                          NaN
#  114999           2021-02-16         Amsterdam                         Java
#
#         application_deadline
#  0       2023-11-12 00:00:00
#  1       2025-06-29 00:00:00
#  2       2026-01-24 00:00:00
#  3       2020-12-09 00:00:00
#  4       2025-07-19 00:00:00
#  ...                     ...
#  114995  2025-11-14 00:00:00
#  114996                  NaN
#  114997  2024-02-09 00:00:00
#  114998  2024-09-04 00:00:00
#  114999  2021-01-02 00:00:00
#
#  [115000 rows x 4 columns]>
#  'San Francisco' 'Frankfurt' 'Pune' 'London' 'New York' 'Rio de Janeiro'
#  'Tel Aviv' 'Hyderabad' 'Hamburg' 'Chennai' 'Denver' 'Austin' 'Cambridge'
#  'Mumbai' 'Eindhoven' 'Montreal' 'Chicago' 'Toronto' 'Gurugram' 'Noida'
#  'Bangalore' 'Seattle' 'Boston' 'Abu Dhabi' 'Herzliya' 'Berlin'
#  'Edinburgh' 'Paris' 'Sao Paulo' 'Melbourne' 'Vancouver' 'Singapore'
#  'Amsterdam' 'Waterloo' 'Dubai' 'Lyon' 'Manchester' 'Dublin' 'Sydney'
#  'Not Specified']
#
#
# Column: salary_currency
# ['EUR' 'USD' 'INR' 'GBP' 'BRL' 'ILS' 'SGD' 'CAD' 'AED' 'AUD']
#
#
# Column: posting_date
# ['2023-09-21' '2025-05-11' '2025-12-01' ... '2025-11-29' '2025-06-30'
#  '2026-01-29']
#
#
# Column: application_deadline
# ['2023-11-12 00:00:00' '2025-06-29 00:00:00' '2026-01-24 00:00:00' ...
#  '2026-10-23 00:00:00' '2020-06-19 00:00:00' '2019-01-17 00:00:00']
#
#
# Column: date_position_filled
# ['2023-11-20'
#  <bound method DataFrame.mode of        date_position_filled job_location_city primary_programming_language  \
#  0                2023-11-20            Munich                           Go
#  1                       NaN               NaN                       Python
#  2                2026-02-08     San Francisco                           Go
#  3                2020-12-21         Frankfurt                            R
#  4                2025-09-15              Pune                          NaN
#  ...                     ...               ...                          ...
#  114995           2025-12-21         Cambridge                       Kotlin
#  114996                  NaN               NaN                            R
#  114997                  NaN          Waterloo                          SQL
#  114998                  NaN            Mumbai                          NaN
#  114999           2021-02-16         Amsterdam                         Java
#
#         application_deadline
#  0       2023-11-12 00:00:00
#  1       2025-06-29 00:00:00
#  2       2026-01-24 00:00:00
#  3       2020-12-09 00:00:00
#  4       2025-07-19 00:00:00
#  ...                     ...
#  114995  2025-11-14 00:00:00
#  114996                  NaN
#  114997  2024-02-09 00:00:00
#  114998  2024-09-04 00:00:00
#  114999  2021-01-02 00:00:00
#
#  [115000 rows x 4 columns]>
#  '2026-02-08' ... '2020-07-12' '2019-01-16' '2019-01-05']
#
#
# Column: position_status
# ['Filled' 'Open' 'Cancelled' 'Withdrawn']
#
#
# Column: salary_min_usd
# ['-1' nan '238800.0' ... '84,700 USD' '$121200' '283600.0']
#
#
# Column: salary_max_usd
# ['-1' nan '274700.0' ... '465000.0' '1060000.0' '406800.0']
#
#
# Column: layoff_within_12_months_flag
# ['N' 'No' '0' 'Yes' '1' 'False' 'Y' 'True']

# %% [markdown]
# - By this we can see that for (layoff_within_12_months_flag , visa_sponsorship_offered) the data is written in different format
# - In this we can see that min and max salary are in str we have to covert it into int

# %%
df["layoff_within_12_months_flag"] = df["layoff_within_12_months_flag"].map({'N':"No", '0' : "No", '1' : "Yes" ,'False':"No" ,'Y':"Yes", 'True':"Yes",'Yes':'Yes','No':'No'})
df["visa_sponsorship_offered"] = df["visa_sponsorship_offered"].map({'N':"No", '0' : "No", '1' : "Yes" ,'False':"No" ,'Y':"Yes", 'True':"Yes",'Yes':'Yes','No':'No'})

df["salary_min_usd"] = pd.to_numeric(df["salary_min_usd"], errors="coerce").astype("Int64")
df["salary_max_usd"] = pd.to_numeric(df["salary_max_usd"], errors="coerce").astype("Int64")

print(df["layoff_within_12_months_flag"].unique())
print(df["visa_sponsorship_offered"].unique())
# Out:
# ['No' 'Yes']
# ['No' 'Yes']

# %%
df.isnull().sum()
# Out:
# job_id                             0
# company_name                       0
# company_type                       0
# sector                             0
# company_size_employees             0
# hq_country                         0
# job_role                           0
# seniority_level                    0
# years_experience_min               0
# years_experience_max               0
# required_tech_stack                0
# primary_programming_language       0
# work_mode                          0
# visa_sponsorship_offered           0
# job_location_country               0
# job_location_city                  0
# salary_currency                    0
# posting_date                       0
# application_deadline               0
# date_position_filled               0
# position_status                    0
# number_of_applicants            1099
# number_of_interview_rounds       432
# offers_extended                  327
# offers_accepted                  327
# salary_min_usd                  5302
# salary_max_usd                  3940
# layoff_within_12_months_flag       0
# dtype: int64

# %%
df[df['salary_min_usd'] > df['salary_max_usd']]
# Out:
#            job_id                company_name company_type         sector  \
# 7       JOB057551               EchoCortex Co          MNC  Cybersecurity
# 187     JOB080791                 NexusShield          MNC     E-commerce
# 335     JOB102070           VertexCompute Inc          MNC     HealthTech
# 702     JOB003325              OnyxSphere Inc     Mid-size         Gaming
# 1231    JOB040177  TideCognition Technologies      Unicorn    Crypto/Web3
# ...           ...                         ...          ...            ...
# 114054  JOB110290               NimbusAcademy     Mid-size     E-commerce
# 114107  JOB077294           VertexCompute Inc          MNC     HealthTech
# 114168  JOB062092                 NexusShield          MNC     E-commerce
# 114235  JOB007311        MeridianCare Systems      Startup     E-commerce
# 114837  JOB108136                BeaconCampus     Mid-size           SaaS
#
#         company_size_employees hq_country                       job_role  \
# 7                       128882        USA      Embedded Systems Engineer
# 187                     335703      India                 Cloud Engineer
# 335                     100246      India                    SOC Analyst
# 702                       6442        USA      Embedded Systems Engineer
# 1231                     15512  Australia              Security Engineer
# ...                        ...        ...                            ...
# 114054                    4526     France  Application Security Engineer
# 114107                   75526      India              Software Engineer
# 114168                  295592      India             Penetration Tester
# 114235                     406  Australia             Analytics Engineer
# 114837                    2413     France        Infrastructure Engineer
#
#        seniority_level  years_experience_min  years_experience_max  ...  \
# 7                Entry                     0                     4  ...
# 187             Senior                     5                    11  ...
# 335             Senior                     6                    10  ...
# 702                Mid                     3                     7  ...
# 1231            Senior                     6                     9  ...
# ...                ...                   ...                   ...  ...
# 114054          Senior                     6                     9  ...
# 114107       Principal                    13                    24  ...
# 114168             Mid                     3                     5  ...
# 114235             Mid                     2                     5  ...
# 114837          Intern                     0                     0  ...
#
#                                      application_deadline  \
# 7                                     2024-05-25 00:00:00
# 187                                   2024-12-07 00:00:00
# 335                                   2025-01-24 00:00:00
# 702                                   2026-03-10 00:00:00
# 1231                                  2023-02-20 00:00:00
# ...                                                   ...
# 114054                                2021-04-20 00:00:00
# 114107                                2026-09-20 00:00:00
# 114168                                2026-05-12 00:00:00
# 114235  <bound method DataFrame.mode of        date_po...
# 114837                                2019-03-03 00:00:00
#
#                                      date_position_filled position_status  \
# 7                                              2024-05-29          Filled
# 187                                            2025-01-05          Filled
# 335                                            2025-03-06          Filled
# 702                                            2026-02-02          Filled
# 1231                                           2023-02-23          Filled
# ...                                                   ...             ...
# 114054                                         2021-03-26          Filled
# 114107                                         2026-09-03          Filled
# 114168                                         2026-05-28          Filled
# 114235                                         2022-06-20          Filled
# 114837  <bound method DataFrame.mode of        date_po...       Cancelled
#
#        number_of_applicants number_of_interview_rounds offers_extended  \
# 7                     258.0                        3.0             1.0
# 187                    60.0                        3.0             1.0
# 335                   168.0                        4.0             1.0
# 702                   276.0                        3.0             1.0
# 1231                   52.0                        5.0             1.0
# ...                     ...                        ...             ...
# 114054                128.0                        5.0             1.0
# 114107                 30.0                        5.0             1.0
# 114168                 91.0                        2.0             1.0
# 114235                 97.0                        4.0             1.0
# 114837                 92.0                        2.0             0.0
#
#        offers_accepted salary_min_usd salary_max_usd  \
# 7                  1.0         131100         103900
# 187                1.0         153900         132400
# 335                1.0         182900         140800
# 702                1.0          71800          65300
# 1231               1.0         208900         169200
# ...                ...            ...            ...
# 114054             1.0         166200         123800
# 114107             1.0         209300         167400
# 114168             1.0         112100          86700
# 114235             1.0         125300          93600
# 114837             0.0          47600          38500
#
#        layoff_within_12_months_flag
# 7                                No
# 187                              No
# 335                              No
# 702                              No
# 1231                            Yes
# ...                             ...
# 114054                           No
# 114107                           No
# 114168                           No
# 114235                          Yes
# 114837                           No
#
# [437 rows x 28 columns]

# %%
df.drop(df[df['salary_min_usd'] > df['salary_max_usd']].index, inplace=True, axis=0)

# %%
df.describe()
# Out:
#        company_size_employees  years_experience_min  years_experience_max  \
# count           112563.000000         112563.000000         112563.000000
# mean            105393.428169              3.004175              6.665050
# std             102107.224215              3.093260              5.073785
# min                 10.000000              0.000000              0.000000
# 25%               6042.000000              1.000000              3.000000
# 50%              88368.000000              2.000000              6.000000
# 75%             169850.000000              5.000000              9.000000
# max             488674.000000             24.000000             24.000000
#
#        number_of_applicants  number_of_interview_rounds  offers_extended  \
# count         111466.000000               112132.000000    112236.000000
# mean             181.869745                    3.308092         1.348560
# std              438.698480                    1.418512         1.455033
# min               -5.000000                    1.000000         0.000000
# 25%               62.000000                    2.000000         1.000000
# 50%              119.000000                    3.000000         1.000000
# 75%              213.000000                    4.000000         1.000000
# max            36816.000000                    8.000000         8.000000
#
#        offers_accepted  salary_min_usd  salary_max_usd
# count    112236.000000        107261.0        108623.0
# mean          1.195918   114540.708785   141787.272263
# std           1.121905    57516.499623    91785.409717
# min           0.000000            -1.0            -1.0
# 25%           1.000000         75800.0         92000.0
# 50%           1.000000        105300.0        128200.0
# 75%           1.000000        145700.0        177500.0
# max          10.000000        531800.0       3552000.0

# %% [markdown]
# 1. In no of applicant min value is -5 which not possible
# 2. Also in min_salary and max_salary value is -1 which not possible
# 3. for company_size_employees, number_of_applicants, offers_accepted, offers_extended Mean and sd is similar means it is highly spreadable

# %%
df.drop(df[df['salary_max_usd']<0].index, inplace=True, axis=0)
df.drop(df[df['salary_min_usd']<0].index, inplace=True, axis=0)
df.drop(df[df['number_of_applicants']<0].index, inplace=True, axis=0)

# %% [markdown]
# ## UNIVARIATE

# %%
# company_size_employees
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.histplot(df['company_size_employees'], bins=30, kde=True)
plt.title('Distribution of Company Size (Employees)')

plt.subplot(1,2,2)
sns.boxplot(x='company_size_employees', data=df)
plt.title('Boxplot of Company Size (Employees)')

plt.show()

# %% [markdown]
# Mostly company have smaller Company_size_employee but few company has larger size

# %%
# years_experience_min
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.histplot(df['years_experience_min'], bins=30, kde=True)
plt.title('Distribution of Years of Experience (Minimum)')

plt.subplot(1,2,2)
sns.boxplot(x='years_experience_min', data=df)
plt.title('Boxplot of Years of Experience (Minimum)')

plt.show()

# %% [markdown]
# Minimum Expierence needed for a company is mostly 0-5 year but there ar company needed more expierenced employee

# %%
# years_experience_max
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.histplot(df['years_experience_max'], bins=30, kde=True)
plt.title('Distribution of Years of Experience (Maximum)')

plt.subplot(1,2,2)
sns.boxplot(x='years_experience_max', data=df)
plt.title('Boxplot of Years of Experience (Maximum)')

plt.show()

# %% [markdown]
# Maximum Expierence needed for a company is mostly 1-10 year but there are company that allow more expierenced employee

# %%
# number_of_applicants
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.histplot(df['number_of_applicants'], bins=30, kde=True)
plt.ylim(0,120000)
plt.title('Distribution of Number of Applicants')

plt.subplot(1,2,2)
sns.boxplot(x='number_of_applicants', data=df)
plt.title('Boxplot of Number of Applicants')

plt.show()

# %% [markdown]
# for No_of_applicant there are outlier it is need to be removed above 12000

# %%
# number_of_interview_rounds
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.histplot(df['number_of_interview_rounds'], bins=30, kde=True)
plt.title('Distribution of Number of Interview Rounds')

plt.subplot(1,2,2)
sns.boxplot(x='number_of_interview_rounds', data=df)
plt.title('Boxplot of Number of Interview Rounds')

plt.show()

# %% [markdown]
# maximum company conduct 2-4 round of interview

# %%
# offers_extended
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.histplot(df['offers_extended'], bins=30, kde=True)
plt.title('Distribution of Offers Extended')

plt.subplot(1,2,2)
sns.boxplot(x='offers_extended', data=df)
plt.title('Boxplot of offers_extended')

plt.show()

# %%
# offers_accepted
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.histplot(df['offers_accepted'], bins=30, kde=True)
plt.title('Distribution of Offers accepted')

plt.subplot(1,2,2)
sns.boxplot(x='offers_accepted', data=df)
plt.title('Boxplot of offers_accepted')

plt.show()

# %% [markdown]
# Almost every company extend only 1 offer and applicant accept only one offer

# %%
# salary_min_usd
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.histplot(df['salary_min_usd'], bins=30, kde=True)
plt.title('Distribution of Salary Minimum')

plt.subplot(1,2,2)
sns.boxplot(x='salary_min_usd', data=df)
plt.title('Boxplot of Salary Minimum')

plt.show()

# %%
# salary_max_usd
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.histplot(df['salary_max_usd'], bins=30, kde=True)
plt.title('Distribution of Salary Maximum')

plt.subplot(1,2,2)
sns.boxplot(x='salary_max_usd', data=df)
plt.xscale('log')
plt.title('Boxplot of Salary Maximum')

plt.show()

# %% [markdown]
# By all these Graph I saw that there is Mid outlier but all these outlier are justified and real world data
# so i prefer to fill miising value of int colomn by median

# %%
# Column for which we need to remove the outlier

# company_size_employees
# years_experience_min
# years_experience_max
# number_of_applicants
# salary_min_usd
# salary_max_usd

# %%
median_imputer = SimpleImputer(strategy='median')
df[int_null_val_cols] = median_imputer.fit_transform(df[int_null_val_cols])

# %%
df.isnull().sum()
# Out:
# job_id                          0
# company_name                    0
# company_type                    0
# sector                          0
# company_size_employees          0
# hq_country                      0
# job_role                        0
# seniority_level                 0
# years_experience_min            0
# years_experience_max            0
# required_tech_stack             0
# primary_programming_language    0
# work_mode                       0
# visa_sponsorship_offered        0
# job_location_country            0
# job_location_city               0
# salary_currency                 0
# posting_date                    0
# application_deadline            0
# date_position_filled            0
# position_status                 0
# number_of_applicants            0
# number_of_interview_rounds      0
# offers_extended                 0
# offers_accepted                 0
# salary_min_usd                  0
# salary_max_usd                  0
# layoff_within_12_months_flag    0
# dtype: int64

# %%
for col in df.select_dtypes(include=["object"]):
    print(f"Column: {col}")
    print(df[col].unique())
    print("\n")
# Out:
# Column: job_id
# ['JOB018462' 'JOB110011' 'JOB073462' ... 'JOB006013' 'JOB063108'
#  'JOB006559']
#
#
# Column: company_name
# ['DriftLearn' 'AnchorBuzz Labs' 'KiteSphere' 'AetherNode Co'
#  'QuantumBuzz Technologies' 'SpireCloud' 'NimbusFlow'
#  'VantageChain Systems' 'PinnacleBlock' 'EchoVita Technologies'
#  'MeridianToken' 'CobaltWealth' 'BeaconStack Co'
#  'LumenArcade Technologies' 'EchoCortex Co' 'VertexCompute Inc'
#  'PinnacleLedger Labs' 'AstraCognition' 'PrismSphere' 'NovaFleet'
#  'PrismRoute Technologies' 'MeridianShield Labs' 'DriftGame Co'
#  'DriftSkill Inc' 'RidgeAI' 'CatalystWellness Inc' 'EchoTrade Co'
#  'OnyxBuzz Inc' 'NexusShield' 'FusionTrade' 'VantageSphere'
#  'CobaltAcademy Labs' 'SolaceFlow Inc' 'AstraSuite' 'SolaceShop Labs'
#  'VantageFlow' 'DriftGame' 'LumenNeural Inc' 'LatticeReach Systems'
#  'SpireBazaar Co' 'OrbitWorks' 'KitePlay Inc' 'NimbusGame Technologies'
#  'LUMENARCADE TECHNOLOGIES' 'DriftShield Labs' '  OnyxBuzz Co'
#  'CrestMind Systems' 'NovaCare' 'TideFort' 'AetherFleet Inc'
#  'WrenShop Systems' 'OrbitNeural Technologies' 'AetherAI Co'
#  'NexusTrade Labs' 'ZenithReach Systems' 'CatalystHub Co'
#  'QuantumReach Co' 'TideSentinel Technologies' 'NimbusAcademy'
#  'NexusCompute' 'VertexBlock Inc  ' 'OnyxSphere Inc' '  AstraCognition'
#  'EchoFreight Systems' 'WrenShop Technologies' 'ZephyrQuest Co'
#  'RidgeFreight Labs' 'BeaconPixel' 'PrismGuard' 'HelixMed Labs'
#  'RuneCompute' 'HelixFin Inc' 'AstraAcademy' 'GroveSocial'
#  'EchoFreight Labs' 'RuneMarket' 'DriftNeural Systems' 'WrenSocial'
#  'LatticePlay Inc' 'EchoMed' 'HalcyonFleet Systems' 'VertexNode Inc'
#  'FusionTrade  ' 'PinnacleBlock Inc' 'NexusFin Inc' 'HelixVita Co'
#  'OrbitShield Systems' 'FalconAcademy Technologies' 'COBALTWEALTH'
#  'PinnacleToken Technologies' 'QuantumCognition Labs' 'VertexBlock Inc'
#  'NexusToken Technologies' 'EmberReach Technologies' 'AstraSecure Systems'
#  'CobaltBlock Systems' 'NimbusCargo Systems' 'VantageSuite'
#  'QuantumHub Inc' 'NexusWellness Labs' 'PrismMarket Labs' 'AetherLearn'
#  'VertexTrade Systems' 'GroveCapital' 'ZenithShield Inc' 'VertexSkill'
#  'RidgeFleet' 'KiteWorks Inc' 'EmberEdu Labs' 'VantageStack Inc'
#  'ZephyrWealth Technologies' 'AETHERAI CO' 'TideCognition Technologies'
#  '  RidgeFreight Labs' '  NimbusTrade Labs' 'SummitShield Co'
#  'FalconPlay Technologies' 'LatticeLedger Inc' 'SolaceWealth Systems'
#  'RidgeSecure Systems' 'LumenCloud' 'RidgeFleet Labs' 'WrenCampus'
#  'CatalystChain' 'RidgeCargo' 'HalcyonLedger Co' 'HelixRoute Systems'
#  'RuneFleet Co' 'OrbitGame' 'MeridianFleet Co' 'VertexFlow Inc'
#  'DriftQuest' 'NimbusTrade Labs' 'KiteCare' 'OrbitWealth Co' 'HelixGuard'
#  'FusionBazaar Technologies' 'CrestRoute Labs' 'BeaconCampus'
#  'VantageCargo Systems' 'NexusShield  ' 'SPIRECLOUD' 'RuneConnect Co'
#  'CrestLearn' 'tidefort' 'EmberRoute Technologies'
#  'RidgeSecure Systems   ' 'ZenithHealth Systems' 'onyxsphere inc'
#  'NexusSecure' 'NEXUSCOMPUTE' '  OrbitNeural Technologies'
#  'MarrowChain Systems' 'RidgeVita Co' 'AetherNode' 'SpireHub Inc'
#  'MeridianCare Systems' 'CobaltCampus Labs' 'MeridianReach Inc'
#  'RidgeTrade Technologies' 'OnyxBuzz Co' 'OnyxCognition Inc'
#  'pinnacleledger labs' 'HalcyonConnect' 'DriftCognition Technologies'
#  'VertexNeural Technologies' 'HelixPixel' 'TideFort  ' 'PinnacleSphere'
#  'NimbusChain' 'QuantumFort Co' 'HalcyonCampus Technologies'
#  'pinnacleblock inc' 'RIDGECARGO' 'NIMBUSCARGO SYSTEMS' 'VantageVita Co'
#  'ridgefreight labs' 'AstraVault Co' 'SolaceGuard' 'TideQuest'
#  'OnyxNode Labs' 'LatticeHub' 'NexusDesk Labs' 'TideMarket Technologies'
#  'MeridianPixel Co' 'RidgeVita Labs' 'PrismGuard Co' 'SummitMarket'
#  'FableConnect Technologies' 'LatticeMarket Systems' 'AETHERNODE CO'
#  'CatalystConnect Co' 'DriftNode Labs' 'OnyxWorks Systems' 'FableLogix'
#  'NovaArcade Co' 'AstraWellness' 'HALCYONLEDGER CO' 'HalcyonLedger Inc'
#  'NimbusFleet Inc' '  HelixRoute Systems' 'MeridianLogix Co'
#  'VantageLogix' '  CobaltWealth' 'CatalystHealth Labs' '  KiteSphere'
#  '  SolaceFlow Inc' 'ECHOFREIGHT SYSTEMS' 'RidgeCapital'
#  'ZephyrHealth Systems' 'CatalystCapital Labs' '  BeaconStack Co'
#  '  PrismRoute Technologies' 'DriftDesk' 'DRIFTGAME CO' 'HelixStack'
#  'FusionSocial Labs' 'vertexblock inc' 'BeaconPixel ' 'PINNACLEBLOCK'
#  'NovaGrid Inc' 'BeaconFin Inc' '  TideFort' '  NovaFleet'
#  '  DriftSkill Inc' 'SpireGame Labs' 'ONYXCOGNITION INC' 'DriftGame Co '
#  'MeridianSocial' 'AetherFleet Inc  ' 'RuneDesk Systems'
#  'HalcyonToken Labs' 'MeridianToken ' 'FusionMarket Systems'
#  'NexusCompute  ' 'VERTEXTRADE SYSTEMS' 'AetherVault Co' 'ANCHORBUZZ LABS'
#  'fusionfort' 'LatticeReach Systems  ' '  ZenithHealth Systems'
#  'GroveTrade Inc' 'LATTICEREACH SYSTEMS' 'EchoCortex Co  ' 'AetherFlow'
#  'NimbusQuest' 'HelixStack  ' '  OrbitWorks' '  MarrowChain Systems'
#  'driftgame co' 'SpireCloud  ' 'AnchorBuzz Labs  ' 'nimbusflow'
#  '  MeridianFleet Co' 'BEACONSTACK CO' '  NexusShield' 'NEXUSSHIELD'
#  'echocortex co' 'SolaceShop Labs  ' 'ZephyrQuest Co  ' '  PinnacleBlock'
#  'HelixCare Systems' 'SolaceWealth Systems  ' 'astrasuite'
#  'DriftCognition Systems' '  FusionTrade' 'EMBERROUTE TECHNOLOGIES'
#  'HalcyonLedger Co ' 'NEXUSWELLNESS LABS' 'COBALTACADEMY LABS'
#  '  MeridianShield Labs' 'nexusshield' '  ZenithShield Inc' 'BEACONPIXEL'
#  'ORBITNEURAL TECHNOLOGIES' '  AetherAI Co' '  RuneCompute' 'FusionTrade '
#  '  DriftGame Co' 'PinnacleBlock ' 'BeaconFin Inc '
#  'LatticeReach Systems ' 'FusionMind' 'RUNEMARKET' 'PinnaclePixel'
#  'RidgePixel Systems' 'cobaltwealth' 'RIDGEFREIGHT LABS' 'onyxbuzz inc'
#  'PRISMROUTE TECHNOLOGIES' '  AstraSuite' 'grovesocial'
#  '  LatticeReach Systems' 'EchoCortex Co ' '  TideQuest'
#  'meridianreach inc' 'astraacademy' 'ridgefleet labs' 'beaconstack co'
#  'AetherCognition' '  HelixGuard' '  MeridianToken' 'vertexskill'
#  '  VantageSuite' 'LUMENNEURAL INC' 'spirecloud' 'NEXUSTRADE LABS'
#  '  BeaconPixel' 'marrowchain systems' '  PinnacleLedger Labs'
#  'NovaCare  ' 'NOVAFLEET' 'catalystconnect co' 'GROVESOCIAL'
#  'PRISMMARKET LABS' 'NimbusCargo Systems  ' '  NexusCompute' 'FusionFort'
#  'NIMBUSACADEMY' 'ZenithHealth Systems  ' 'BeaconStack Co '
#  'OrbitVault Labs' 'orbitgame' 'kitesphere' 'zenithshield inc'
#  'EMBERREACH TECHNOLOGIES' 'RidgeFleet Labs  '
#  'OrbitNeural Technologies  ' '  VertexBlock Inc' 'EchoFreight Systems  '
#  'RidgeFreight Labs ' 'CobaltWealth  ' 'ZENITHHEALTH SYSTEMS'
#  'BeaconStack Co  ' '  NimbusFlow' 'DriftSkill Inc  '
#  'TideSentinel Technologies  ' 'VertexTrade Systems  ' '  LumenNeural Inc'
#  'AstraSuite ' 'ZephyrWealth Technologies  ' 'NovaFleet  '
#  'PrismRoute Technologies ' 'ASTRAACADEMY' 'MERIDIANTOKEN'
#  'DRIFTSKILL INC' 'OrbitNeural Technologies ' '  SummitMarket'
#  'LATTICEPLAY INC' 'VANTAGECARGO SYSTEMS' 'TIDECOGNITION TECHNOLOGIES'
#  'HELIXGUARD' 'NEXUSTOKEN TECHNOLOGIES' '  EchoMed'
#  '  EmberReach Technologies' 'MERIDIANPIXEL CO' 'LumenAI Inc'
#  'KiteSphere  ' 'SpireCloud ' 'MeridianPixel Co '
#  'PinnacleToken Technologies  ' 'kiteplay inc' 'cobaltacademy labs'
#  'LatticePlay Inc ' 'PINNACLEBLOCK INC' 'echomed' 'nexuswellness labs'
#  'MeridianShield Labs  ' 'emberreach technologies' '  BeaconFin Inc'
#  '  AetherNode Co' 'PinnacleLedger Labs ' 'QuantumReach Co  '
#  '  VertexCompute Inc' 'NexusTrade Labs  ' 'runecompute'
#  'MERIDIANCARE SYSTEMS' 'ORBITSHIELD SYSTEMS' 'MARROWCHAIN SYSTEMS'
#  'RidgeFreight Labs  ' '  OrbitWealth Co' '  PrismGuard' 'RidgeCargo '
#  'zenithhealth systems' 'SummitMarket ' '  FusionBazaar Technologies'
#  '  VertexNode Inc' '  AnchorBuzz Labs' 'meridiantoken' 'RIDGECAPITAL'
#  '  RidgeSecure Systems' 'NexusShield ' 'RidgeVita Co  ' 'aethernode co'
#  'VantageSuite  ' 'TIDEFORT' 'RUNECOMPUTE' 'VERTEXSKILL'
#  'PINNACLELEDGER LABS' '  CatalystWellness Inc' 'WrenSuite Co'
#  '  CatalystConnect Co' 'MeridianShield Labs ' 'MERIDIANSHIELD LABS'
#  'CobaltAcademy Labs ' '  KitePlay Inc' 'VANTAGESUITE'
#  'PINNACLETOKEN TECHNOLOGIES' 'MeridianToken  ' 'LumenAI Inc  '
#  'NEXUSFIN INC' 'pinnacletoken technologies' 'AnchorLogix Technologies'
#  'NimbusFlow  ' 'NimbusGrid Co' 'nexuscompute' 'vertexcompute inc'
#  'ONYXBUZZ INC' 'pinnacleblock' 'VERTEXBLOCK INC' 'GROVETRADE INC'
#  'beaconpixel' 'ASTRACOGNITION' 'PrismMarket Labs  ' 'NovaFleet '
#  'ZEPHYRHEALTH SYSTEMS' 'driftgame co ' 'novafleet '
#  'EchoFreight Systems ' 'nimbusacademy' 'LATTICEMARKET SYSTEMS'
#  'HELIXMED LABS' 'tidecognition technologies' 'NOVACARE'
#  '  QuantumBuzz Technologies' 'VertexBlock Inc '
#  '  TideCognition Technologies' 'HalcyonCampus Technologies  '
#  '  HelixVita Co' 'catalysthub co' 'vertexnode inc' '  NovaCare'
#  'AetherNode Co ' 'VertexCompute Inc  ' 'LumenNeural Inc  '
#  'VERTEXCOMPUTE INC' 'DRIFTSHIELD LABS' 'AnchorBuzz Labs '
#  'EmberEdu Labs ' 'KitePlay Inc ' '  HelixMed Labs' 'PinnacleBlock  '
#  'echofreight systems' 'fusionmarket systems' 'lumenneural inc'
#  'DriftSkill Inc ' 'RIDGETRADE TECHNOLOGIES' 'DRIFTNODE LABS'
#  'RidgeFleet Labs ' 'latticeledger inc' 'CATALYSTCAPITAL LABS'
#  'NimbusTrade Labs ' 'OnyxNode Labs  ' 'RidgeTrade Technologies  '
#  '  DriftDesk' '  LumenArcade Technologies' 'QuantumBuzz Technologies '
#  'KITESPHERE' '  OnyxSphere Inc' 'AetherAI Co  ' 'ridgeai' '  SpireCloud'
#  '  WrenCampus' 'meridianshield labs' 'RuneMarket  ' 'cobaltblock systems'
#  'VantageStack Inc  ' 'AetherAI Co ' 'DriftNeural Systems ' 'ECHOMED'
#  'CRESTLEARN' 'meridianfleet co' 'VANTAGESTACK INC' '  BEACONSTACK CO'
#  'VANTAGESPHERE' 'HelixGuard  ' 'DriftGame Co  ' 'RidgeSecure Systems '
#  '  PinnacleBlock Inc' 'TIDESENTINEL TECHNOLOGIES'
#  'lumenarcade technologies' 'echofreight labs' 'catalystcapital labs'
#  '  FusionMind' 'anchorbuzz labs' 'WRENCAMPUS' 'EmberReach Technologies  '
#  'HELIXFIN INC' 'GroveSocial ' 'VertexCompute Inc ' 'QuantumHub Inc  '
#  '  OnyxBuzz Inc' '  DriftGame' '  NimbusFleet Inc'
#  'LumenArcade Technologies  ' '  NimbusChain' 'SolaceShop Labs '
#  '  CatalystChain' 'ECHOCORTEX CO' 'LumenNeural Inc ' 'DriftNode Labs '
#  '  QuantumCognition Labs' 'AETHERNODE' 'HalcyonToken Labs  '
#  'FUSIONTRADE' 'NIMBUSTRADE LABS' '  AstraAcademy' 'CobaltWealth '
#  'TideCognition Technologies ' 'nexusdesk labs' '  VertexSkill'
#  'helixvita co' 'CatalystWellness Inc  ' 'aetherai co' 'RIDGEVITA CO'
#  '  EchoCortex Co' 'RIDGESECURE SYSTEMS' 'HelixFin Inc ' '  RidgeCargo'
#  'vantagestack inc' '  EchoFreight Labs' 'orbitneural technologies'
#  '  AetherFlow' 'LumenArcade Technologies ' 'QuantumReach Co '
#  '  MeridianCare Systems' 'NIMBUSGAME TECHNOLOGIES' '  KITEPLAY INC'
#  'CatalystChain  ' '  NEXUSCOMPUTE' 'ONYXSPHERE INC' 'OrbitGame '
#  'novacare' 'PrismRoute Technologies  ' 'fusiontrade' '  PinnacleBlock '
#  'BEACONFIN INC' '  EchoFreight Systems' 'OrbitGame  ' 'QUANTUMHUB INC'
#  '  QuantumReach Co' 'AstraSuite  ' 'VERTEXNEURAL TECHNOLOGIES'
#  'EmberReach Technologies ' 'vertexneural technologies' 'AETHERLEARN'
#  'solaceshop labs' 'CATALYSTHUB CO' 'AstraWellness  ' 'fusionmind'
#  '  AetherLearn' 'MeridianCare Systems ' 'HelixRoute Systems '
#  'quantumbuzz technologies' 'RidgeSecure Systems  ' 'NimbusTrade Labs  '
#  'RUNECONNECT CO' 'BeaconPixel  ' '  FableLogix'
#  'ZephyrWealth Technologies ' 'QUANTUMBUZZ TECHNOLOGIES'
#  '  DriftShield Labs' '  VantageSphere' '  CobaltAcademy Labs'
#  'BeaconCampus ' '  NexusSecure' 'KiteCare ' 'HelixMed Labs '
#  'FusionBazaar Technologies  ' 'PinnacleBlock Inc  ' 'driftneural systems'
#  'DriftCognition Systems ' 'MERIDIANFLEET CO' '  RidgeFleet Labs'
#  'ASTRASUITE' '  HalcyonLedger Inc' 'HalcyonFleet Systems  ' 'driftdesk'
#  'ZEPHYRQUEST CO' 'DRIFTNEURAL SYSTEMS' 'TideQuest  ' 'AetherNode Co  '
#  'FALCONPLAY TECHNOLOGIES' 'SolaceGuard ' 'helixmed labs'
#  '  VertexNeural Technologies' 'NovaGrid Inc ' 'NIMBUSFLOW'
#  'MeridianFleet Co   ' 'RuneConnect Co  ' 'zephyrquest co' 'RuneMarket '
#  'SPIREHUB INC' '  SummitShield Co' '  RuneConnect Co' 'helixpixel'
#  'SOLACESHOP LABS' 'helixcare systems' 'AstraCognition '
#  'prismroute technologies' '  NimbusCargo Systems' 'DriftGame  '
#  'AstraAcademy  ' 'driftskill inc' 'MeridianPixel Co  ' 'AstraCognition  '
#  'nimbuscargo systems' 'fusionbazaar technologies' '  OrbitGame'
#  'GroveTrade Inc ' 'DriftShield Labs  ' 'CrestMind Systems  '
#  '  VantageVita Co' 'novafleet' '  SolaceShop Labs' 'MERIDIANLOGIX CO'
#  'ridgecargo' 'FalconPlay Technologies  ' 'NIMBUSGRID CO' '  RUNEMARKET'
#  'LatticeLedger Inc  ' 'RUNEDESK SYSTEMS' '  KiteWorks Inc'
#  'AstraSecure Systems  ' 'LatticeMarket Systems ' 'ONYXNODE LABS'
#  'ASTRASECURE SYSTEMS' '  NimbusGame Technologies' '  RIDGEFREIGHT LABS'
#  'NovaCare ' 'BEACONCAMPUS' 'OrbitShield Systems  ' 'ECHOFREIGHT LABS'
#  'DRIFTLEARN' 'EmberRoute Technologies  ' '  RuneMarket'
#  'ZenithReach Systems ' '  HalcyonFleet Systems' 'KitePlay Inc  '
#  'LUMENCLOUD' '  AetherNode' 'FusionFort  ' 'runeconnect co'
#  '  FusionSocial Labs' 'PinnacleLedger Labs  ' '  DriftQuest'
#  'CobaltWealth   ' 'SOLACEWEALTH SYSTEMS' 'TIDEMARKET TECHNOLOGIES'
#  'CatalystCapital Labs  ' 'solacewealth systems' 'PRISMGUARD'
#  '  ZephyrWealth Technologies' 'AstraVault Co  ' '  VertexTrade Systems'
#  '  CatalystHub Co' '  PinnacleToken Technologies' '  NovaGrid Inc'
#  'HALCYONFLEET SYSTEMS' 'ZEPHYRWEALTH TECHNOLOGIES' 'SUMMITSHIELD CO'
#  'SolaceFlow Inc ' 'ORBITWORKS' 'FUSIONSOCIAL LABS' 'HELIXCARE SYSTEMS'
#  '  DriftSkill Inc  ' 'HelixMed Labs  ' 'VERTEXNODE INC' 'OnyxBuzz Inc  '
#  'QuantumBuzz Technologies  ' 'COBALTCAMPUS LABS' '  RidgeVita Co'
#  'FABLELOGIX' 'WrenCampus  ' 'SolaceFlow Inc  ' 'WrenCampus '
#  'EchoFreight Labs ' 'HalcyonFleet Systems ' '  CobaltBlock Systems'
#  '  VantageStack Inc' 'wrenshop technologies' 'zephyrwealth technologies'
#  '  QuantumHub Inc' 'VertexSkill ' 'NexusWellness Labs  ' 'wrencampus'
#  'TideQuest ' '  OnyxWorks Systems' 'astrasecure systems'
#  'TideSentinel Technologies ' 'WRENSHOP TECHNOLOGIES' 'LATTICELEDGER INC'
#  'OrbitWorks ' 'RIDGEFLEET LABS' 'SOLACEFLOW INC' 'ZENITHSHIELD INC'
#  '  RidgePixel Systems' '  HalcyonLedger Co' 'RidgeCargo  '
#  'AstraAcademy ' 'NEXUSDESK LABS' 'aethernode' 'summitshield co'
#  '  RuneDesk Systems' 'MarrowChain Systems ' 'ORBITGAME'
#  'ridgetrade technologies' 'helixguard' 'PinnacleToken Technologies '
#  'EchoFreight Labs  ' 'DRIFTGAME' 'VantageSphere  ' 'OrbitWorks  '
#  'falconplay technologies' '  NexusWellness Labs' '  DriftLearn'
#  'RuneDesk Systems  ' 'halcyonfleet systems' 'NimbusFlow '
#  'nimbusgame technologies' 'NimbusChain  ' 'latticeplay inc'
#  'LumenCloud  ' 'VertexNode Inc  ' 'NexusToken Technologies  '
#  '  ZephyrQuest Co' 'astravault co' '  ZenithReach Systems' 'AetherFlow '
#  'VantageVita Co  ' 'TIDEQUEST' 'RidgePixel Systems  ' '  NexusFin Inc'
#  '  MeridianPixel Co' 'VantageSuite ' 'FableLogix  '
#  'ZenithReach Systems  ' 'runemarket' 'ridgevita co' 'ridgesecure systems'
#  'NimbusGame Technologies  ' 'KiteSphere ' 'latticemarket systems'
#  'NexusCompute ' '  GroveCapital' 'EmberRoute Technologies '
#  'DriftQuest  ' 'VantageSphere ' 'FUSIONMIND' 'PinnacleBlock   '
#  '  GroveSocial' '  DriftCognition Systems' 'LATTICEHUB' 'ORBITWEALTH CO'
#  'NexusWellness Labs ' '  BeaconCampus' 'meridianlogix co'
#  'spirebazaar co' 'EchoMed ' 'HALCYONTOKEN LABS' 'CobaltBlock Systems  '
#  'tidequest' 'NOVAARCADE CO' 'onyxnode labs' 'LatticePlay Inc  '
#  'GroveSocial  ' 'FUSIONBAZAAR TECHNOLOGIES' 'QUANTUMREACH CO' 'TideFort '
#  '  nexuscompute' 'VertexTrade Systems ' '  FalconPlay Technologies'
#  'RuneCompute  ' 'prismmarket labs' 'halcyonledger co' 'crestmind systems'
#  '  HalcyonConnect' 'MarrowChain Systems  ' 'ZenithShield Inc  '
#  'HalcyonLedger Inc ' 'halcyonledger inc' '  SolaceWealth Systems'
#  '  NexusToken Technologies' '  AetherVault Co'
#  '  TideSentinel Technologies' 'DriftNeural Systems  ' 'HelixVita Co '
#  '  SpireBazaar Co' 'KiteCare  ' 'solaceflow inc' 'CatalystHub Co  '
#  'driftlearn' '  NimbusAcademy' 'TideCognition Technologies  '
#  'SUMMITMARKET' '  LatticeHub' '  EchoTrade Co' 'WrenSocial  '
#  'NexusDesk Labs ' 'RuneConnect Co ' '  NexusTrade Labs'
#  '  WrenShop Systems' '  LatticeLedger Inc' 'meridianpixel co'
#  'ZENITHREACH SYSTEMS' 'RUNEFLEET CO' 'AstraSecure Systems '
#  'KITEWORKS INC' '  AstraSecure Systems' '  DriftNeural Systems'
#  'WrenShop Technologies  ' 'VertexNeural Technologies  '
#  '  LatticePlay Inc' 'meridiancare systems' 'vantagesphere'
#  'VantageVita Co ' 'LatticeLedger Inc ' 'HELIXSTACK' 'OnyxBuzz Inc '
#  'RuneDesk Systems ' 'DRIFTQUEST' 'catalystchain' 'latticereach systems'
#  '  HelixFin Inc' 'RIDGEFLEET' '  QUANTUMBUZZ TECHNOLOGIES' 'AetherNode '
#  '  QuantumFort Co' 'catalystwellness inc' 'RidgeVita Co '
#  'EchoTrade Co  ' 'nexusfin inc' 'nexussecure' '  HalcyonToken Labs'
#  '  NexusCompute ' 'DriftLearn  ' 'meridiansocial' 'VERTEXFLOW INC'
#  'VANTAGEFLOW' 'PinnaclePixel  ' 'AetherNode  ' 'HalcyonLedger Co  '
#  'helixroute systems' 'summitmarket' 'FableLogix ' 'driftgame'
#  '  MeridianLogix Co' 'aetherfleet inc' 'DriftGame ' 'MeridianFleet Co  '
#  'VertexSkill  ' '  DriftNode Labs' 'MeridianFleet Co ' 'runefleet co'
#  'KiteWorks Inc ' 'MeridianLogix Co  ' 'MeridianSocial  '
#  'tidesentinel technologies' 'RuneCompute ' 'PinnacleBlock Inc '
#  'FalconAcademy Technologies  ' 'aethervault co' '  NovaArcade Co'
#  '  RidgeFleet' 'AetherLearn ' 'astracognition' 'AETHERVAULT CO'
#  'COBALTBLOCK SYSTEMS' 'quantumcognition labs' 'nimbuschain'
#  'HelixCare Systems ' 'CatalystConnect Co ' 'QUANTUMCOGNITION LABS'
#  'AetherCognition  ' 'CatalystConnect Co  ' '  EmberRoute Technologies'
#  'SummitShield Co  ' 'beaconcampus' '  OnyxCognition Inc'
#  '  AetherFleet Inc' 'AETHERCOGNITION' '  MeridianReach Inc'
#  'NovaArcade Co  ' '  SpireHub Inc' 'CATALYSTCONNECT CO']
#
#
# Column: company_type
# ['Mid-size' 'MNC' 'Unicorn' 'FAANG-tier' 'Startup']
#
#
# Column: sector
# ['Cloud/Infra' 'HealthTech' 'Social/AdTech' 'SaaS' 'Fintech' 'Crypto/Web3'
#  'AI/ML' 'E-commerce' 'EdTech' 'Logistics' 'Cybersecurity' 'Gaming'
#  'cloud/infra' 'gaming' 'crypto/web3' 'ai/ml' 'saas' 'edtech' 'logistics'
#  'social/adtech' 'cybersecurity' 'healthtech' 'e-commerce' 'fintech']
#
#
# Column: hq_country
# ['USA' 'Brazil' 'UK' 'Singapore' 'India' 'Germany' 'France' 'Netherlands'
#  'Canada' 'Israel' 'UAE' 'Australia' 'Ireland']
#
#
# Column: job_role
# ['Mobile Engineer (iOS)' 'QA Engineer' 'Research Scientist'
#  'Product Manager' 'Data Engineer' 'UI Designer' 'Product Designer'
#  'Mobile Engineer (Android)' 'Platform Engineer' 'Full Stack Engineer'
#  'Backend Engineer' 'Application Security Engineer' 'Software Engineer'
#  'SOC Analyst' 'Machine Learning Engineer' 'DevOps Engineer'
#  'Frontend Engineer' 'Data Analyst' 'Embedded Systems Engineer'
#  'Product Owner' 'Infrastructure Engineer' 'Associate Product Manager'
#  'Analytics Engineer' 'Data Scientist' 'Technical Program Manager'
#  'UX Designer' 'Site Reliability Engineer' 'Security Engineer'
#  'Penetration Tester' 'Cloud Engineer' 'INFRASTRUCTURE ENGINEER'
#  'UX Researcher' 'technical program manager' ' Frontend Engineer'
#  'Mobile Engineer (iOS) ' 'Full Stack Engineer '
#  'SITE RELIABILITY ENGINEER' ' Analytics Engineer' 'devops engineer'
#  'mobile engineer (ios)' 'DATA ENGINEER' 'APPLICATION SECURITY ENGINEER'
#  'cloud engineer' ' Embedded Systems Engineer' 'infrastructure engineer'
#  ' Product Owner' ' Application Security Engineer' 'Product Owner '
#  'Embedded Systems Engineer ' 'PLATFORM ENGINEER'
#  ' Technical Program Manager' 'Mobile Engineer (Android) '
#  'Product Manager ' 'Software Engineer ' ' Mobile Engineer (iOS)'
#  'frontend engineer' ' Data Engineer' 'product owner' ' UI Designer'
#  'data scientist' 'UX Designer ' 'ui designer' 'platform engineer'
#  'Research Scientist ' 'Data Engineer ' 'data engineer' 'backend engineer'
#  ' Penetration Tester' 'QA Engineer ' 'software engineer' 'qa engineer'
#  'Security Engineer ' 'embedded systems engineer' ' Product Designer'
#  'SOC Analyst ' ' Data Scientist' ' UX Designer'
#  'ASSOCIATE PRODUCT MANAGER' ' UX Researcher' 'DevOps Engineer '
#  'FRONTEND ENGINEER' 'mobile engineer (android)' ' QA Engineer '
#  'Cloud Engineer ' ' Infrastructure Engineer' 'site reliability engineer'
#  'product designer' ' SOC Analyst' ' Full Stack Engineer' 'UX RESEARCHER'
#  'Backend Engineer ' ' Security Engineer' 'SOFTWARE ENGINEER'
#  'FULL STACK ENGINEER' 'Frontend Engineer ' 'EMBEDDED SYSTEMS ENGINEER'
#  'associate product manager' 'Data Analyst ' 'research scientist'
#  ' Mobile Engineer (Android)' ' QA Engineer' ' Product Manager'
#  'Machine Learning Engineer ' 'ux designer' 'MOBILE ENGINEER (IOS)'
#  'penetration tester' ' Cloud Engineer' 'data analyst'
#  'analytics engineer' ' Research Scientist' 'machine learning engineer'
#  'Analytics Engineer ' 'Associate Product Manager '
#  ' Site Reliability Engineer' 'DATA ANALYST' ' Data Analyst'
#  'UI Designer ' ' Backend Engineer' 'QA ENGINEER' 'product manager'
#  'Site Reliability Engineer ' 'DEVOPS ENGINEER'
#  'Technical Program Manager ' 'application security engineer'
#  'CLOUD ENGINEER' 'DATA SCIENTIST' ' DevOps Engineer' ' Software Engineer'
#  ' Platform Engineer' 'BACKEND ENGINEER' ' Machine Learning Engineer'
#  'RESEARCH SCIENTIST' 'SOC ANALYST' 'PRODUCT DESIGNER' 'ux researcher'
#  'MACHINE LEARNING ENGINEER' 'ANALYTICS ENGINEER' 'security engineer'
#  'Data Scientist ' 'Application Security Engineer ' 'full stack engineer'
#  'MOBILE ENGINEER (ANDROID)' 'Product Designer ' 'SECURITY ENGINEER'
#  'PENETRATION TESTER' ' Associate Product Manager'
#  'Infrastructure Engineer ' 'soc analyst' 'Penetration Tester '
#  'UI DESIGNER' 'UX Researcher ' 'TECHNICAL PROGRAM MANAGER' 'UX DESIGNER'
#  'PRODUCT OWNER' 'PRODUCT MANAGER' 'Platform Engineer '
#  ' FRONTEND ENGINEER' ' Data Analyst ' ' Mobile Engineer (iOS) '
#  ' DATA ENGINEER']
#
#
# Column: seniority_level
# ['Mid' 'Lead' 'Entry' 'Senior' 'Intern' 'Principal']
#
#
# Column: required_tech_stack
# ['C++, TypeScript, Python, Kotlin' 'Swift, C++, Kotlin, Python'
#  'dbt, Spark, Python, Snowflake, Airflow' ...
#  'Spark, TensorFlow, Python, Snowflake'
#  'React, Java, Swift, TypeScript, Kotlin'
#  'Kotlin, C++, Python, Node.js, Swift']
#
#
# Column: primary_programming_language
# ['Python' 'Go' 'R'
#  <bound method DataFrame.mode of        date_position_filled job_location_city primary_programming_language  \
#  0                2023-11-20            Munich                           Go
#  1                       NaN               NaN                       Python
#  2                2026-02-08     San Francisco                           Go
#  3                2020-12-21         Frankfurt                            R
#  4                2025-09-15              Pune                          NaN
#  ...                     ...               ...                          ...
#  114995           2025-12-21         Cambridge                       Kotlin
#  114996                  NaN               NaN                            R
#  114997                  NaN          Waterloo                          SQL
#  114998                  NaN            Mumbai                          NaN
#  114999           2021-02-16         Amsterdam                         Java
#
#         application_deadline
#  0       2023-11-12 00:00:00
#  1       2025-06-29 00:00:00
#  2       2026-01-24 00:00:00
#  3       2020-12-09 00:00:00
#  4       2025-07-19 00:00:00
#  ...                     ...
#  114995  2025-11-14 00:00:00
#  114996                  NaN
#  114997  2024-02-09 00:00:00
#  114998  2024-09-04 00:00:00
#  114999  2021-01-02 00:00:00
#
#  [115000 rows x 4 columns]>
#  'Scala' 'JavaScript' 'TypeScript' 'C++' 'Kotlin' 'Bash' 'Java' 'SQL'
#  'Swift' 'C' 'Unknown' 'TBD']
#
#
# Column: work_mode
# ['Remote' 'Hybrid' 'Onsite' 'HYBRID' 'In-office' 'hybrid' 'remote' 'WFH'
#  'onsite' 'REMOTE' 'ONSITE' 'On-site' 'Work From Home']
#
#
# Column: visa_sponsorship_offered
# ['No' 'Yes']
#
#
# Column: job_location_country
# ['USA' 'Germany' 'India' 'UK' 'Brazil' 'Israel' 'Singapore' 'Netherlands'
#  'Canada' 'UAE' 'France' 'Australia' 'Ireland']
#
#
# Column: job_location_city
# [<bound method DataFrame.mode of        date_position_filled job_location_city primary_programming_language  \
#  0                2023-11-20            Munich                           Go
#  1                       NaN               NaN                       Python
#  2                2026-02-08     San Francisco                           Go
#  3                2020-12-21         Frankfurt                            R
#  4                2025-09-15              Pune                          NaN
#  ...                     ...               ...                          ...
#  114995           2025-12-21         Cambridge                       Kotlin
#  114996                  NaN               NaN                            R
#  114997                  NaN          Waterloo                          SQL
#  114998                  NaN            Mumbai                          NaN
#  114999           2021-02-16         Amsterdam                         Java
#
#         application_deadline
#  0       2023-11-12 00:00:00
#  1       2025-06-29 00:00:00
#  2       2026-01-24 00:00:00
#  3       2020-12-09 00:00:00
#  4       2025-07-19 00:00:00
#  ...                     ...
#  114995  2025-11-14 00:00:00
#  114996                  NaN
#  114997  2024-02-09 00:00:00
#  114998  2024-09-04 00:00:00
#  114999  2021-01-02 00:00:00
#
#  [115000 rows x 4 columns]>
#  'San Francisco' 'Frankfurt' 'Pune' 'London' 'New York' 'Rio de Janeiro'
#  'Tel Aviv' 'Hyderabad' 'Hamburg' 'Chennai' 'Denver' 'Austin' 'Cambridge'
#  'Mumbai' 'Eindhoven' 'Montreal' 'Chicago' 'Toronto' 'Gurugram' 'Munich'
#  'Noida' 'Bangalore' 'Seattle' 'Boston' 'Abu Dhabi' 'Herzliya' 'Berlin'
#  'Edinburgh' 'Paris' 'Sao Paulo' 'Melbourne' 'Vancouver' 'Singapore'
#  'Amsterdam' 'Waterloo' 'Dubai' 'Lyon' 'Manchester' 'Dublin' 'Sydney'
#  'Not Specified']
#
#
# Column: salary_currency
# ['USD' 'EUR' 'INR' 'GBP' 'BRL' 'ILS' 'SGD' 'CAD' 'AED' 'AUD']
#
#
# Column: posting_date
# ['2025-05-11' '2025-12-01' '2020-11-21' ... '2025-11-29' '2025-06-30'
#  '2026-01-29']
#
#
# Column: application_deadline
# ['2025-06-29 00:00:00' '2026-01-24 00:00:00' '2020-12-09 00:00:00' ...
#  '2026-10-23 00:00:00' '2020-06-19 00:00:00' '2019-01-17 00:00:00']
#
#
# Column: date_position_filled
# [<bound method DataFrame.mode of        date_position_filled job_location_city primary_programming_language  \
#  0                2023-11-20            Munich                           Go
#  1                       NaN               NaN                       Python
#  2                2026-02-08     San Francisco                           Go
#  3                2020-12-21         Frankfurt                            R
#  4                2025-09-15              Pune                          NaN
#  ...                     ...               ...                          ...
#  114995           2025-12-21         Cambridge                       Kotlin
#  114996                  NaN               NaN                            R
#  114997                  NaN          Waterloo                          SQL
#  114998                  NaN            Mumbai                          NaN
#  114999           2021-02-16         Amsterdam                         Java
#
#         application_deadline
#  0       2023-11-12 00:00:00
#  1       2025-06-29 00:00:00
#  2       2026-01-24 00:00:00
#  3       2020-12-09 00:00:00
#  4       2025-07-19 00:00:00
#  ...                     ...
#  114995  2025-11-14 00:00:00
#  114996                  NaN
#  114997  2024-02-09 00:00:00
#  114998  2024-09-04 00:00:00
#  114999  2021-01-02 00:00:00
#
#  [115000 rows x 4 columns]>
#  '2026-02-08' '2020-12-21' ... '2020-07-12' '2019-01-16' '2019-01-05']
#
#
# Column: position_status
# ['Open' 'Filled' 'Cancelled' 'Withdrawn']
#
#
# Column: layoff_within_12_months_flag
# ['No' 'Yes']

# %%
# company_type, sector and hq_country                      

plt.figure(figsize=(16,4))
plt.subplot(1,3,1)
sns.countplot(x=df["company_type"])
plt.xticks(rotation=90)
plt.subplot(1,3,2)
sns.countplot(x=df["sector"])
plt.xticks(rotation=90)
plt.subplot(1,3,3)
sns.countplot(x=df["hq_country"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Most of the hirings are from MNC
# - HealthTech ,FinTech , E-commerce , EdTech are the popular sector for hiring
# - Majority of hiring are form USA

# %%
# seniority_level, work_mode and primary_programming_language                        

plt.figure(figsize=(16,4))
plt.subplot(1,3,1)
sns.countplot(x=df["seniority_level"])
plt.xticks(rotation=90)
plt.subplot(1,3,2)
sns.countplot(x=df["primary_programming_language"])
plt.xticks(rotation=90)
plt.subplot(1,3,3)
sns.countplot(x=df["work_mode"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Hiring is mostly for Mid,Entry,Senior level
# - Go and Python is in demand in industry
# - Hybrid, Remote and Onsite Mode is more preffered as compare to other

# %%
# visa_sponsorship_offered, job_location_country and salary_currency                        

plt.figure(figsize=(16,4))
plt.subplot(1,3,1)
sns.countplot(x=df["visa_sponsorship_offered"])
plt.xticks(rotation=90)
plt.subplot(1,3,2)
sns.countplot(x=df["job_location_country"])
plt.xticks(rotation=90)
plt.subplot(1,3,3)
sns.countplot(x=df["salary_currency"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - As we see clearly mostly job are form USA and India so Salaray is also inn INR and USD
# - VISA Sponsorship offrered are note there in most of the company

# %%
# layoff_within_12_months_flag, position_status                         

plt.figure(figsize=(16,4))
plt.subplot(1,2,1)
sns.countplot(x=df["layoff_within_12_months_flag"])
plt.xticks(rotation=90)
plt.subplot(1,2,2)
sns.countplot(x=df["position_status"])
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# - Mostly applicant stay the company and do not resign
# - MOstly jon Hiring are filled

# %% [markdown]
# ## BIVARIATE ANALYISIS

# %%
plt.figure(figsize=(8,7))
sns.heatmap(df.corr(numeric_only = True) , annot = True , fmt = '.1f' , cmap = 'YlGnBu' , annot_kws = {'size':6})
# Out:
# <Axes: >

# %% [markdown]
# ## With the help of heatmap we decide to compare following column
# - Years_Expierience_min vs salary_min_usd, Years_Expierience_max, number_of_interview_rounds
# - Years_Expierience_max vs number_of_interview_rounds
# - offers_extended vs offers_accepted

# %%
plt.figure(figsize=(16,7))
plt.subplot(1,2,1)
sns.scatterplot(x='salary_min_usd', y='years_experience_min', data=df)

plt.subplot(1,2,2)
sns.scatterplot(x='salary_max_usd', y='years_experience_max', data=df)
# Out:
# <Axes: xlabel='salary_max_usd', ylabel='years_experience_max'>

# %% [markdown]
# - As we increase min and max axpierence than min and max salary also increased

# %%
plt.figure(figsize=(16,7))
plt.subplot(1,2,1)
sns.scatterplot(x='number_of_interview_rounds', y='years_experience_max', data=df)

plt.subplot(1,2,2)
sns.scatterplot(x='number_of_interview_rounds', y='years_experience_min', data=df)
# Out:
# <Axes: xlabel='number_of_interview_rounds', ylabel='years_experience_min'>

# %% [markdown]
# It is clearly show for higher expierience there is more no of interview rounds

# %%
plt.figure(figsize=(16,7))
plt.subplot(1,2,1)
sns.scatterplot(x='offers_extended', y='offers_accepted', data=df)
# Out:
# <Axes: xlabel='offers_extended', ylabel='offers_accepted'>

# %% [markdown]
# As the offer extend the acception is also increase

# %%
df.columns
# Out:
# Index(['job_id', 'company_name', 'company_type', 'sector',
#        'company_size_employees', 'hq_country', 'job_role', 'seniority_level',
#        'years_experience_min', 'years_experience_max', 'required_tech_stack',
#        'primary_programming_language', 'work_mode', 'visa_sponsorship_offered',
#        'job_location_country', 'job_location_city', 'salary_currency',
#        'posting_date', 'application_deadline', 'date_position_filled',
#        'position_status', 'number_of_applicants', 'number_of_interview_rounds',
#        'offers_extended', 'offers_accepted', 'salary_min_usd',
#        'salary_max_usd', 'layoff_within_12_months_flag'],
#       dtype='object')

# %%
plt.figure(figsize=(9,7))

sns.countplot(data=df, x='sector', hue='layoff_within_12_months_flag')
plt.title('Layoffs by Sector')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# For every Sector there is no layoff within 12 month

# %%
sns.boxplot(data=df, x='work_mode', y='salary_max_usd')
plt.title('Salary by Work Mode')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# For Remote, Hybrid,Onsite there is max salary

# %%
sns.boxplot(data=df, x='visa_sponsorship_offered', y='salary_max_usd')
plt.title('Visa Sponsorship vs Salary')
plt.show()

# %% [markdown]
# ## MultiVariant

# %%
sns.boxplot(data=df, x='work_mode', y='salary_max_usd', hue='visa_sponsorship_offered')
plt.title('Salary by Work Mode & Visa Sponsorship')
plt.show()
